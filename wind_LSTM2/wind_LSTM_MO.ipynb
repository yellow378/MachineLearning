# %%
import pandas as pd
import numpy as np
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
my_font = FontProperties(fname=r"c:\windows\fonts\SimHei.ttf",size=12)

# %%
class WindDataSet(Dataset):
    def __init__(self,path,num_steps=50):
        self.data = []
        file = pd.read_csv(path,skiprows=1)
        self.feature = np.array(file[[ "Month", "Day", "Hour", "Minute", "surface air pressure (Pa)",
                                       "relative humidity at 2m (%)", "surface precipitation rate (mm/h)",
                                         "air temperature at 10m (C)", "wind direction at 10m (deg)",
                                         "wind speed at 10m (m/s)"]])
        self.target = np.array(file["wind speed at 10m (m/s)"])
        wind_len = len(self.feature)
        for i in range(wind_len-num_steps-1):
            self.data.append((self.feature[i:i+num_steps],self.target[i+num_steps]))
        self.data = self.data[:int(len(self.data)/250)*250]
    def __len__(self):
        return len(self.data)   
    def __getitem__(self,index):
        seq,pre = self.data[index]
        return seq,pre

# %%
def try_gpu(i=0):
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')
try_gpu()
# Out:
# device(type='cpu')

# %%
INPUT_SIZE=10
HIDDEN_SIZE=50
BATCH_SIZE=250
OUTPUT_SIZE=1
NUM_LAYERS=2

class lstm(nn.Module):
    def __init__(self):
        super(lstm,self).__init__()
        self.rnn = nn.LSTM(input_size=INPUT_SIZE,hidden_size=HIDDEN_SIZE,num_layers=NUM_LAYERS)
        self.fc = nn.Linear(HIDDEN_SIZE,OUTPUT_SIZE)
    def forward(self,x,state):
        x = torch.transpose(x,dim0=0,dim1=1).reshape((x.shape[1],-1,INPUT_SIZE))
        out,state = self.rnn(x,state)
        out = self.fc(out)
        return out[-1],state
    def begin_state(self,batch_size,device):
        return (torch.zeros((2,batch_size,HIDDEN_SIZE),device=device),torch.zeros((2,batch_size, HIDDEN_SIZE), device=device))

# %%
net = lstm()
lr = 0.001
device = try_gpu()
print(device)
net = net.to(device)
optimizer = torch.optim.Adam(net.parameters(),lr=lr)
loss = nn.MSELoss()
epochs = 10
num_steps=50
# Out:
# cpu

# %%
def grad_clipping(net,theta):
    if isinstance(net,nn.Module):
        params = [p for p in net.parameters() if p.requires_grad]
    else:
        params = net.params
    norm = torch.sqrt(sum(torch.sum((p.grad ** 2)) for p in params))
    if norm > theta:
        for param in params:
            param.grad[:] *= theta/norm

# %%
def train_epoch(epoch,net,train_loader,device,train_loss):
    net = net.to(device)
    net.train()
    runing_loss=0
    for batch_idx,(X,y) in enumerate(train_loader):
        state=net.begin_state(batch_size=BATCH_SIZE, device=device)
        for s in state:
            s.detach_()
        optimizer.zero_grad()
        X,y = X.to(torch.float32).to(device),y.to(torch.float32).T.to(device)
        #print(X.shape,y.shape)
        y_hat,state = net(X,state)
        y_hat = y_hat.reshape(-1)
        l = loss(y_hat,y).mean()
        l.backward()
        grad_clipping(net, 1)
        optimizer.step()
        runing_loss += l.item()
        if batch_idx%400 == 399:
            print(f'epoch:{epoch+1},batch_idx:{batch_idx+1},running_loss:{runing_loss/400}')
            train_loss.append(l.item())
            runing_loss=0

# %%
dataset = WindDataSet('../data/wind_dataset144-2014/wind_dataset144/1.csv',num_steps)
print(dataset.__len__())
# Out:
# 105000

# %%
def save_net(path = 'wind_10input.pt', net=None):
    torch.save(net.state_dict(),path)
# save_net(net=net)

# %%
def train(epochs):
    train_loss = []
    for epoch in range(epochs):
        for i in range(120):
            dataset = WindDataSet(f'./datasets/{i}.csv',num_steps)
            train_loader = DataLoader(dataset,batch_size=BATCH_SIZE,shuffle=False,num_workers=0)
            train_epoch(epoch,net,train_loader,device,train_loss)
        print(f'###epoch:{epoch+1},train_loss:{train_loss[-1]}')
        save_net(path=f"multidata-epoch{epoch}.pt",net=net.to('cpu'))
        #net = net.to(device)

# %%
train(epochs)
# Out:
# epoch:1,batch_idx:400,running_loss:6.056187234446407
# epoch:1,batch_idx:400,running_loss:7.098025044947863
# epoch:1,batch_idx:400,running_loss:5.9750065587461
# epoch:1,batch_idx:400,running_loss:7.234809423238039
# epoch:1,batch_idx:400,running_loss:9.239081171005964
# epoch:1,batch_idx:400,running_loss:10.610373565405608
# epoch:1,batch_idx:400,running_loss:11.19194963991642
# epoch:1,batch_idx:400,running_loss:11.511015555858613
# epoch:1,batch_idx:400,running_loss:11.777962229624391
# epoch:1,batch_idx:400,running_loss:12.346329095736145
# epoch:1,batch_idx:400,running_loss:12.914522670656442
# epoch:1,batch_idx:400,running_loss:13.47696782708168
# epoch:1,batch_idx:400,running_loss:9.607671436071396
# epoch:1,batch_idx:400,running_loss:10.072358027547597
# epoch:1,batch_idx:400,running_loss:10.322921684682369
# epoch:1,batch_idx:400,running_loss:10.655389100164175
# epoch:1,batch_idx:400,running_loss:11.00442012757063
# epoch:1,batch_idx:400,running_loss:11.304035099893808
# epoch:1,batch_idx:400,running_loss:11.59073522940278
# epoch:1,batch_idx:400,running_loss:11.855901428163051
# epoch:1,batch_idx:400,running_loss:11.810803345739842
# epoch:1,batch_idx:400,running_loss:11.95103049173951
# epoch:1,batch_idx:400,running_loss:12.251500012800097
# epoch:1,batch_idx:400,running_loss:12.43623656153679
# epoch:1,batch_idx:400,running_loss:10.974366575628519
# epoch:1,batch_idx:400,running_loss:11.185656116753817
# epoch:1,batch_idx:400,running_loss:11.531512341201305
# epoch:1,batch_idx:400,running_loss:11.937685886919498
# epoch:1,batch_idx:400,running_loss:11.932663117200136
# epoch:1,batch_idx:400,running_loss:11.707421687543393
# epoch:1,batch_idx:400,running_loss:12.116413583606482
# epoch:1,batch_idx:400,running_loss:12.472344870716334
# epoch:1,batch_idx:400,running_loss:11.81134986758232
# epoch:1,batch_idx:400,running_loss:11.65462116420269
# epoch:1,batch_idx:400,running_loss:12.092446049824357
# epoch:1,batch_idx:400,running_loss:12.046482427492737
# epoch:1,batch_idx:400,running_loss:12.962631843090058
# epoch:1,batch_idx:400,running_loss:12.812574020922185
# epoch:1,batch_idx:400,running_loss:12.48822611361742
# epoch:1,batch_idx:400,running_loss:12.479942552745342
# epoch:1,batch_idx:400,running_loss:12.410567910224199
# epoch:1,batch_idx:400,running_loss:12.280747252851725
# epoch:1,batch_idx:400,running_loss:12.761345809102059
# epoch:1,batch_idx:400,running_loss:13.10136397883296
# epoch:1,batch_idx:400,running_loss:12.25229799747467
# epoch:1,batch_idx:400,running_loss:11.773657026439905
# epoch:1,batch_idx:400,running_loss:12.294936214089393
# epoch:1,batch_idx:400,running_loss:12.20751974850893
# epoch:1,batch_idx:400,running_loss:13.779317968487739
# epoch:1,batch_idx:400,running_loss:13.587980260699988
# epoch:1,batch_idx:400,running_loss:13.347091200202703
# epoch:1,batch_idx:400,running_loss:13.411074740663171
# epoch:1,batch_idx:400,running_loss:13.123980847373605
# epoch:1,batch_idx:400,running_loss:12.660039249956608
# epoch:1,batch_idx:400,running_loss:12.845985792130232
# epoch:1,batch_idx:400,running_loss:12.994414855539798
# epoch:1,batch_idx:400,running_loss:12.632188160419464
# epoch:1,batch_idx:400,running_loss:12.162300162017345
# epoch:1,batch_idx:400,running_loss:12.376639780551194
# epoch:1,batch_idx:400,running_loss:12.278981951922178
# epoch:1,batch_idx:400,running_loss:14.055537469685078
# epoch:1,batch_idx:400,running_loss:13.80399959653616
# epoch:1,batch_idx:400,running_loss:13.63527892947197
# epoch:1,batch_idx:400,running_loss:13.845357464253903
# epoch:1,batch_idx:400,running_loss:13.93545601516962
# epoch:1,batch_idx:400,running_loss:13.433070229589939
# epoch:1,batch_idx:400,running_loss:13.036491737663745
# epoch:1,batch_idx:400,running_loss:12.934834174662829
# epoch:1,batch_idx:400,running_loss:12.831313172727823
# epoch:1,batch_idx:400,running_loss:12.484537912905216
# epoch:1,batch_idx:400,running_loss:12.184298492372037
# epoch:1,batch_idx:400,running_loss:12.083044578433038
# epoch:1,batch_idx:400,running_loss:14.03711558163166
# epoch:1,batch_idx:400,running_loss:14.240484589487314
# epoch:1,batch_idx:400,running_loss:13.88811734057963
# epoch:1,batch_idx:400,running_loss:13.892429103404284
# epoch:1,batch_idx:400,running_loss:14.204773614555597
# epoch:1,batch_idx:400,running_loss:14.034223148673773
# epoch:1,batch_idx:400,running_loss:13.604517597034574
# epoch:1,batch_idx:400,running_loss:13.309238689690828
# epoch:1,batch_idx:400,running_loss:12.940280068218708
# epoch:1,batch_idx:400,running_loss:12.64387384980917
# epoch:1,batch_idx:400,running_loss:12.350039439499378
# epoch:1,batch_idx:400,running_loss:12.191323635280133
# epoch:1,batch_idx:400,running_loss:13.724825608730317
# epoch:1,batch_idx:400,running_loss:14.624073612689973
# epoch:1,batch_idx:400,running_loss:14.418336467444897
# epoch:1,batch_idx:400,running_loss:14.18032157279551
# epoch:1,batch_idx:400,running_loss:14.486535278707743
# epoch:1,batch_idx:400,running_loss:14.529870345890522
# epoch:1,batch_idx:400,running_loss:14.128940317034722
# epoch:1,batch_idx:400,running_loss:13.621421427577735
# epoch:1,batch_idx:400,running_loss:13.297862206995488
# epoch:1,batch_idx:400,running_loss:12.834351001381874
# epoch:1,batch_idx:400,running_loss:12.43355762630701
# epoch:1,batch_idx:400,running_loss:12.181541585624219
# epoch:1,batch_idx:400,running_loss:13.717327454686165
# epoch:1,batch_idx:400,running_loss:14.299432145357132
# epoch:1,batch_idx:400,running_loss:14.738833894133569
# epoch:1,batch_idx:400,running_loss:14.705326198637486
# epoch:1,batch_idx:400,running_loss:14.665745235681534
# epoch:1,batch_idx:400,running_loss:14.521685504764319
# epoch:1,batch_idx:400,running_loss:14.104030538797378
# epoch:1,batch_idx:400,running_loss:13.554997663199902
# epoch:1,batch_idx:400,running_loss:13.404380994141102
# epoch:1,batch_idx:400,running_loss:13.1162451633811
# epoch:1,batch_idx:400,running_loss:12.62297808021307
# epoch:1,batch_idx:400,running_loss:12.243697477281094
# epoch:1,batch_idx:400,running_loss:13.844696590304375
# epoch:1,batch_idx:400,running_loss:13.949310932457447
# epoch:1,batch_idx:400,running_loss:14.56332825154066
# epoch:1,batch_idx:400,running_loss:14.678821110576392
# epoch:1,batch_idx:400,running_loss:14.521220989227295
# epoch:1,batch_idx:400,running_loss:14.330148457884789
# epoch:1,batch_idx:400,running_loss:13.949428449571133
# epoch:1,batch_idx:400,running_loss:13.563580252826213
# epoch:1,batch_idx:400,running_loss:13.327215322554112
# epoch:1,batch_idx:400,running_loss:13.064322582185268
# epoch:1,batch_idx:400,running_loss:12.61789810627699
# epoch:1,batch_idx:400,running_loss:12.267737384736538
# ###epoch:1,train_loss:6.348955154418945
# epoch:2,batch_idx:400,running_loss:5.8394046097248795
# epoch:2,batch_idx:400,running_loss:7.097959150671959
# epoch:2,batch_idx:400,running_loss:5.974972338229418
# epoch:2,batch_idx:400,running_loss:7.234732443094254
# epoch:2,batch_idx:400,running_loss:9.239056299924851
# epoch:2,batch_idx:400,running_loss:10.61034760594368
# epoch:2,batch_idx:400,running_loss:11.191915899217129
# epoch:2,batch_idx:400,running_loss:11.511006182283163
# epoch:2,batch_idx:400,running_loss:11.777958369925619
# epoch:2,batch_idx:400,running_loss:12.346332930624484
# epoch:2,batch_idx:400,running_loss:12.914520823061466
# epoch:2,batch_idx:400,running_loss:13.476969400942325
# epoch:2,batch_idx:400,running_loss:9.607671294510364
# epoch:2,batch_idx:400,running_loss:10.072357286512851
# epoch:2,batch_idx:400,running_loss:10.322921552956105
# epoch:2,batch_idx:400,running_loss:10.655389248132705
# epoch:2,batch_idx:400,running_loss:11.004419905543328
# epoch:2,batch_idx:400,running_loss:11.304034384042025
# epoch:2,batch_idx:400,running_loss:11.59073516458273
# epoch:2,batch_idx:400,running_loss:11.855901518166066
# epoch:2,batch_idx:400,running_loss:11.810802920758725
# epoch:2,batch_idx:400,running_loss:11.951029905229808
# epoch:2,batch_idx:400,running_loss:12.251499700769783
# epoch:2,batch_idx:400,running_loss:12.436236814707518
# epoch:2,batch_idx:400,running_loss:10.974366832971572
# epoch:2,batch_idx:400,running_loss:11.185656175166368
# epoch:2,batch_idx:400,running_loss:11.531512756049633
# epoch:2,batch_idx:400,running_loss:11.937686488330364
# epoch:2,batch_idx:400,running_loss:11.932662939280272
# epoch:2,batch_idx:400,running_loss:11.707421636283398
# epoch:2,batch_idx:400,running_loss:12.116413071006537
# epoch:2,batch_idx:400,running_loss:12.472344646602869
# epoch:2,batch_idx:400,running_loss:11.811350131481886
# epoch:2,batch_idx:400,running_loss:11.654621231853962
# epoch:2,batch_idx:400,running_loss:12.092446497306227
# epoch:2,batch_idx:400,running_loss:12.046481334716082
# epoch:2,batch_idx:400,running_loss:12.962631532251836
# epoch:2,batch_idx:400,running_loss:12.812573684304953
# epoch:2,batch_idx:400,running_loss:12.48822608679533
# epoch:2,batch_idx:400,running_loss:12.479942605644464
# epoch:2,batch_idx:400,running_loss:12.410568255707622
# epoch:2,batch_idx:400,running_loss:12.280747511088848
# epoch:2,batch_idx:400,running_loss:12.761345722079277
# epoch:2,batch_idx:400,running_loss:13.101363879591226
# epoch:2,batch_idx:400,running_loss:12.2522979465127
# epoch:2,batch_idx:400,running_loss:11.773656928390265
# epoch:2,batch_idx:400,running_loss:12.29493568211794
# epoch:2,batch_idx:400,running_loss:12.207519636452197
# epoch:2,batch_idx:400,running_loss:13.779318436980247
# epoch:2,batch_idx:400,running_loss:13.587980297356843
# epoch:2,batch_idx:400,running_loss:13.347092989087106
# epoch:2,batch_idx:400,running_loss:13.411076163053513
# epoch:2,batch_idx:400,running_loss:13.123981231227518
# epoch:2,batch_idx:400,running_loss:12.660039226561786
# epoch:2,batch_idx:400,running_loss:12.84598577901721
# epoch:2,batch_idx:400,running_loss:12.994414642453194
# epoch:2,batch_idx:400,running_loss:12.632188279032707
# epoch:2,batch_idx:400,running_loss:12.1623009416461
# epoch:2,batch_idx:400,running_loss:12.376639411598443
# epoch:2,batch_idx:400,running_loss:12.278981682509183
# epoch:2,batch_idx:400,running_loss:14.055537491440774
# epoch:2,batch_idx:400,running_loss:13.803999598920345
# epoch:2,batch_idx:400,running_loss:13.63527901083231
# epoch:2,batch_idx:400,running_loss:13.845358919352293
# epoch:2,batch_idx:400,running_loss:13.935455976575613
# epoch:2,batch_idx:400,running_loss:13.433070392012596
# epoch:2,batch_idx:400,running_loss:13.036491642445325
# epoch:2,batch_idx:400,running_loss:12.934833343327046
# epoch:2,batch_idx:400,running_loss:12.831313129812479
# epoch:2,batch_idx:400,running_loss:12.48453757673502
# epoch:2,batch_idx:400,running_loss:12.184298889786005
# epoch:2,batch_idx:400,running_loss:12.083044697195291
# epoch:2,batch_idx:400,running_loss:14.037116237878799
# epoch:2,batch_idx:400,running_loss:14.240483940690757
# epoch:2,batch_idx:400,running_loss:13.888118244074285
# epoch:2,batch_idx:400,running_loss:13.892431698814034
# epoch:2,batch_idx:400,running_loss:14.204773548841477
# epoch:2,batch_idx:400,running_loss:14.034223336875439
# epoch:2,batch_idx:400,running_loss:13.604518183246254
# epoch:2,batch_idx:400,running_loss:13.309238329827785
# epoch:2,batch_idx:400,running_loss:12.940280515700579
# epoch:2,batch_idx:400,running_loss:12.643873173296452
# epoch:2,batch_idx:400,running_loss:12.350038937926293
# epoch:2,batch_idx:400,running_loss:12.19132402509451
# epoch:2,batch_idx:400,running_loss:13.724825433194637
# epoch:2,batch_idx:400,running_loss:14.624073035120965
# epoch:2,batch_idx:400,running_loss:14.41833648070693
# epoch:2,batch_idx:400,running_loss:14.180322114899754
# epoch:2,batch_idx:400,running_loss:14.48653585359454
# epoch:2,batch_idx:400,running_loss:14.529870904535056
# epoch:2,batch_idx:400,running_loss:14.128940388560295
# epoch:2,batch_idx:400,running_loss:13.62142148718238
# epoch:2,batch_idx:400,running_loss:13.297862127423286
# epoch:2,batch_idx:400,running_loss:12.834351525604724
# epoch:2,batch_idx:400,running_loss:12.433557518720626
# epoch:2,batch_idx:400,running_loss:12.181541073024272
# epoch:2,batch_idx:400,running_loss:13.717327380776405
# epoch:2,batch_idx:400,running_loss:14.299431485533715
# epoch:2,batch_idx:400,running_loss:14.738832755833863
# epoch:2,batch_idx:400,running_loss:14.705326287448406
# epoch:2,batch_idx:400,running_loss:14.665745276510716
# epoch:2,batch_idx:400,running_loss:14.521684972941875
# epoch:2,batch_idx:400,running_loss:14.104030345082283
# epoch:2,batch_idx:400,running_loss:13.554997882544994
# epoch:2,batch_idx:400,running_loss:13.404381378293037
# epoch:2,batch_idx:400,running_loss:13.11624558866024
# epoch:2,batch_idx:400,running_loss:12.622977875173092
# epoch:2,batch_idx:400,running_loss:12.243697209656238
# epoch:2,batch_idx:400,running_loss:13.844697170853614
# epoch:2,batch_idx:400,running_loss:13.949311174154282
# epoch:2,batch_idx:400,running_loss:14.563329397439956
# epoch:2,batch_idx:400,running_loss:14.678819824159145
# epoch:2,batch_idx:400,running_loss:14.52122105807066
# epoch:2,batch_idx:400,running_loss:14.330148808658123
# epoch:2,batch_idx:400,running_loss:13.949428530037403
# epoch:2,batch_idx:400,running_loss:13.56358041971922
# epoch:2,batch_idx:400,running_loss:13.327215622663498
# epoch:2,batch_idx:400,running_loss:13.064322768747807
# epoch:2,batch_idx:400,running_loss:12.617898181974887
# epoch:2,batch_idx:400,running_loss:12.26773683220148
# ###epoch:2,train_loss:6.348955154418945
# epoch:3,batch_idx:400,running_loss:5.839404557868838
# epoch:3,batch_idx:400,running_loss:7.097959015518427
# epoch:3,batch_idx:400,running_loss:5.974972326084972
# epoch:3,batch_idx:400,running_loss:7.2347324225306515
# epoch:3,batch_idx:400,running_loss:9.239056230187416
# epoch:3,batch_idx:400,running_loss:10.610347792804241
# epoch:3,batch_idx:400,running_loss:11.191915771067142
# epoch:3,batch_idx:400,running_loss:11.511006371080875
# epoch:3,batch_idx:400,running_loss:11.777958420291544
# epoch:3,batch_idx:400,running_loss:12.346332971155643
# epoch:3,batch_idx:400,running_loss:12.914520750939847
# epoch:3,batch_idx:400,running_loss:13.476969502568245
# epoch:3,batch_idx:400,running_loss:9.607671581059694
# epoch:3,batch_idx:400,running_loss:10.072356865108013
# epoch:3,batch_idx:400,running_loss:10.322921782433987
# epoch:3,batch_idx:400,running_loss:10.655389161258936
# epoch:3,batch_idx:400,running_loss:11.004420226961374
# epoch:3,batch_idx:400,running_loss:11.304034395962953
# epoch:3,batch_idx:400,running_loss:11.590735247433186
# epoch:3,batch_idx:400,running_loss:11.855901057571172
# epoch:3,batch_idx:400,running_loss:11.810802322477102
# epoch:3,batch_idx:400,running_loss:11.951030384749174
# epoch:3,batch_idx:400,running_loss:12.251499757692217
# epoch:3,batch_idx:400,running_loss:12.436236673891544
# epoch:3,batch_idx:400,running_loss:10.974367039203644
# epoch:3,batch_idx:400,running_loss:11.185656074732542
# epoch:3,batch_idx:400,running_loss:11.53151277333498
# epoch:3,batch_idx:400,running_loss:11.937686437219382
# epoch:3,batch_idx:400,running_loss:11.932663387358188
# epoch:3,batch_idx:400,running_loss:11.70742179095745
# epoch:3,batch_idx:400,running_loss:12.116413807272911
# epoch:3,batch_idx:400,running_loss:12.472344961613416
# epoch:3,batch_idx:400,running_loss:11.811349760591984
# epoch:3,batch_idx:400,running_loss:11.654621243178845
# epoch:3,batch_idx:400,running_loss:12.092446247711777
# epoch:3,batch_idx:400,running_loss:12.046482171788812
# epoch:3,batch_idx:400,running_loss:12.962632105648517
# epoch:3,batch_idx:400,running_loss:12.81257366925478
# epoch:3,batch_idx:400,running_loss:12.488226483017206
# epoch:3,batch_idx:400,running_loss:12.47994320705533
# epoch:3,batch_idx:400,running_loss:12.41056757926941
# epoch:3,batch_idx:400,running_loss:12.280746660232545
# epoch:3,batch_idx:400,running_loss:12.761345432251693
# epoch:3,batch_idx:400,running_loss:13.101363885551692
# epoch:3,batch_idx:400,running_loss:12.252298180311918
# epoch:3,batch_idx:400,running_loss:11.77365698978305
# epoch:3,batch_idx:400,running_loss:12.294935316741466
# epoch:3,batch_idx:400,running_loss:12.20752010166645
# epoch:3,batch_idx:400,running_loss:13.779318563640118
# epoch:3,batch_idx:400,running_loss:13.587980166524648
# epoch:3,batch_idx:400,running_loss:13.347090348750353
# epoch:3,batch_idx:400,running_loss:13.4110761526227
# epoch:3,batch_idx:400,running_loss:13.123981633782387
# epoch:3,batch_idx:400,running_loss:12.66004005804658
# epoch:3,batch_idx:400,running_loss:12.845985940247774
# epoch:3,batch_idx:400,running_loss:12.994414467513561
# epoch:3,batch_idx:400,running_loss:12.632188434004783
# epoch:3,batch_idx:400,running_loss:12.162300299555064
# epoch:3,batch_idx:400,running_loss:12.37663930311799
# epoch:3,batch_idx:400,running_loss:12.278982365578413
# epoch:3,batch_idx:400,running_loss:14.05553659528494
# epoch:3,batch_idx:400,running_loss:13.80399977505207
# epoch:3,batch_idx:400,running_loss:13.635279326364397
# epoch:3,batch_idx:400,running_loss:13.845356982201338
# epoch:3,batch_idx:400,running_loss:13.93545558527112
# epoch:3,batch_idx:400,running_loss:13.43306981921196
# epoch:3,batch_idx:400,running_loss:13.036491393297911
# epoch:3,batch_idx:400,running_loss:12.934834393113851
# epoch:3,batch_idx:400,running_loss:12.831313766241074
# epoch:3,batch_idx:400,running_loss:12.484538395702838
# epoch:3,batch_idx:400,running_loss:12.184298800379038
# epoch:3,batch_idx:400,running_loss:12.083044639229774
# epoch:3,batch_idx:400,running_loss:14.037115990519524
# epoch:3,batch_idx:400,running_loss:14.240483723729849
# epoch:3,batch_idx:400,running_loss:13.888116751685738
# epoch:3,batch_idx:400,running_loss:13.892428720071912
# epoch:3,batch_idx:400,running_loss:14.204772957265376
# epoch:3,batch_idx:400,running_loss:14.034223550409079
# epoch:3,batch_idx:400,running_loss:13.604518908262254
# epoch:3,batch_idx:400,running_loss:13.309238480180502
# epoch:3,batch_idx:400,running_loss:12.940280346423387
# epoch:3,batch_idx:400,running_loss:12.643873340189456
# epoch:3,batch_idx:400,running_loss:12.35003860116005
# epoch:3,batch_idx:400,running_loss:12.19132227987051
# epoch:3,batch_idx:400,running_loss:13.724825839996338
# epoch:3,batch_idx:400,running_loss:14.624073403775691
# epoch:3,batch_idx:400,running_loss:14.418337051421403
# epoch:3,batch_idx:400,running_loss:14.180321761220693
# epoch:3,batch_idx:400,running_loss:14.486535850018264
# epoch:3,batch_idx:400,running_loss:14.529870278388263
# epoch:3,batch_idx:400,running_loss:14.128940397799015
# epoch:3,batch_idx:400,running_loss:13.621421529650688
# epoch:3,batch_idx:400,running_loss:13.29786227375269
# epoch:3,batch_idx:400,running_loss:12.834351548552513
# epoch:3,batch_idx:400,running_loss:12.433557358682156
# epoch:3,batch_idx:400,running_loss:12.181541168689728
# epoch:3,batch_idx:400,running_loss:13.717327255308629
# epoch:3,batch_idx:400,running_loss:14.299432692229749
# epoch:3,batch_idx:400,running_loss:14.738833756446839
# epoch:3,batch_idx:400,running_loss:14.705326469242573
# epoch:3,batch_idx:400,running_loss:14.665745182484388
# epoch:3,batch_idx:400,running_loss:14.521684975475074
# epoch:3,batch_idx:400,running_loss:14.104030552208423
# epoch:3,batch_idx:400,running_loss:13.55499763339758
# epoch:3,batch_idx:400,running_loss:13.404381132423877
# epoch:3,batch_idx:400,running_loss:13.116245297789574
# epoch:3,batch_idx:400,running_loss:12.622977768480778
# epoch:3,batch_idx:400,running_loss:12.24369701564312
# epoch:3,batch_idx:400,running_loss:13.844696871340275
# epoch:3,batch_idx:400,running_loss:13.9493110871315
# epoch:3,batch_idx:400,running_loss:14.563329129219055
# epoch:3,batch_idx:400,running_loss:14.67882105410099
# epoch:3,batch_idx:400,running_loss:14.521221190690994
# epoch:3,batch_idx:400,running_loss:14.33014857172966
# epoch:3,batch_idx:400,running_loss:13.949428262114525
# epoch:3,batch_idx:400,running_loss:13.563580036461353
# epoch:3,batch_idx:400,running_loss:13.327215062081814
# epoch:3,batch_idx:400,running_loss:13.064322583675384
# epoch:3,batch_idx:400,running_loss:12.617897426187993
# epoch:3,batch_idx:400,running_loss:12.267737297713756
# ###epoch:3,train_loss:6.348957538604736
# epoch:4,batch_idx:400,running_loss:5.839404588788748
# epoch:4,batch_idx:400,running_loss:7.0979595002532
# epoch:4,batch_idx:400,running_loss:5.9749723174422975
# epoch:4,batch_idx:400,running_loss:7.234732169061899
# epoch:4,batch_idx:400,running_loss:9.239056392908097
# epoch:4,batch_idx:400,running_loss:10.610347512960434
# epoch:4,batch_idx:400,running_loss:11.191916169375181
# epoch:4,batch_idx:400,running_loss:11.511006260216236
# epoch:4,batch_idx:400,running_loss:11.777958515658975
# epoch:4,batch_idx:400,running_loss:12.346332630217075
# epoch:4,batch_idx:400,running_loss:12.914520310163498
# epoch:4,batch_idx:400,running_loss:13.476969365179539
# epoch:4,batch_idx:400,running_loss:9.607671410292387
# epoch:4,batch_idx:400,running_loss:10.072357217967511
# epoch:4,batch_idx:400,running_loss:10.32292155444622
# epoch:4,batch_idx:400,running_loss:10.655389615595341
# epoch:4,batch_idx:400,running_loss:11.00441965982318
# epoch:4,batch_idx:400,running_loss:11.304034455567598
# epoch:4,batch_idx:400,running_loss:11.59073476433754
# epoch:4,batch_idx:400,running_loss:11.855901620090007
# epoch:4,batch_idx:400,running_loss:11.81080254599452
# epoch:4,batch_idx:400,running_loss:11.951030292063951
# epoch:4,batch_idx:400,running_loss:12.251499576941132
# epoch:4,batch_idx:400,running_loss:12.436236747354268
# epoch:4,batch_idx:400,running_loss:10.974366485774517
# epoch:4,batch_idx:400,running_loss:11.18565649613738
# epoch:4,batch_idx:400,running_loss:11.531512537002563
# epoch:4,batch_idx:400,running_loss:11.937685973346234
# epoch:4,batch_idx:400,running_loss:11.932663002759218
# epoch:4,batch_idx:400,running_loss:11.707421642243862
# epoch:4,batch_idx:400,running_loss:12.116413035094737
# epoch:4,batch_idx:400,running_loss:12.472344913482665
# epoch:4,batch_idx:400,running_loss:11.811350020319223
# epoch:4,batch_idx:400,running_loss:11.654621270895005
# epoch:4,batch_idx:400,running_loss:12.092446533069015
# epoch:4,batch_idx:400,running_loss:12.046481681540609
# epoch:4,batch_idx:400,running_loss:12.96263209283352
# epoch:4,batch_idx:400,running_loss:12.812574297487735
# epoch:4,batch_idx:400,running_loss:12.488226210176945
# epoch:4,batch_idx:400,running_loss:12.47994231685996
# epoch:4,batch_idx:400,running_loss:12.410567644387484
# epoch:4,batch_idx:400,running_loss:12.280746736526488
# epoch:4,batch_idx:400,running_loss:12.761345561295748
# epoch:4,batch_idx:400,running_loss:13.101364063173532
# epoch:4,batch_idx:400,running_loss:12.252298116385937
# epoch:4,batch_idx:400,running_loss:11.773656879365443
# epoch:4,batch_idx:400,running_loss:12.294935424923898
# epoch:4,batch_idx:400,running_loss:12.207519706785678
# epoch:4,batch_idx:400,running_loss:13.77931833088398
# epoch:4,batch_idx:400,running_loss:13.587980177551508
# epoch:4,batch_idx:400,running_loss:13.347093084156514
# epoch:4,batch_idx:400,running_loss:13.411076076030731
# epoch:4,batch_idx:400,running_loss:13.12398097127676
# epoch:4,batch_idx:400,running_loss:12.66003951355815
# epoch:4,batch_idx:400,running_loss:12.845985838174819
# epoch:4,batch_idx:400,running_loss:12.9944148658216
# epoch:4,batch_idx:400,running_loss:12.632188858091832
# epoch:4,batch_idx:400,running_loss:12.162300457209348
# epoch:4,batch_idx:400,running_loss:12.376639532893897
# epoch:4,batch_idx:400,running_loss:12.2789818559587
# epoch:4,batch_idx:400,running_loss:14.05553667396307
# epoch:4,batch_idx:400,running_loss:13.80399946257472
# epoch:4,batch_idx:400,running_loss:13.635278817787766
# epoch:4,batch_idx:400,running_loss:13.845359072685241
# epoch:4,batch_idx:400,running_loss:13.935455573350191
# epoch:4,batch_idx:400,running_loss:13.433070450425149
# epoch:4,batch_idx:400,running_loss:13.03648991368711
# epoch:4,batch_idx:400,running_loss:12.934833352267741
# epoch:4,batch_idx:400,running_loss:12.831313059478997
# epoch:4,batch_idx:400,running_loss:12.484537982195615
# epoch:4,batch_idx:400,running_loss:12.184298534542322
# epoch:4,batch_idx:400,running_loss:12.083044789582491
# epoch:4,batch_idx:400,running_loss:14.037115487456322
# epoch:4,batch_idx:400,running_loss:14.240484431535005
# epoch:4,batch_idx:400,running_loss:13.888117149397731
# epoch:4,batch_idx:400,running_loss:13.892428502589464
# epoch:4,batch_idx:400,running_loss:14.204773000329732
# epoch:4,batch_idx:400,running_loss:14.034223101586104
# epoch:4,batch_idx:400,running_loss:13.604517998993396
# epoch:4,batch_idx:400,running_loss:13.309238170832396
# epoch:4,batch_idx:400,running_loss:12.940279886424541
# epoch:4,batch_idx:400,running_loss:12.643873389661312
# epoch:4,batch_idx:400,running_loss:12.350039567649365
# epoch:4,batch_idx:400,running_loss:12.19132249802351
# epoch:4,batch_idx:400,running_loss:13.724825570583343
# epoch:4,batch_idx:400,running_loss:14.624073561131954
# epoch:4,batch_idx:400,running_loss:14.418335770070552
# epoch:4,batch_idx:400,running_loss:14.180321119204164
# epoch:4,batch_idx:400,running_loss:14.48653645798564
# epoch:4,batch_idx:400,running_loss:14.529871296733617
# epoch:4,batch_idx:400,running_loss:14.128940314352512
# epoch:4,batch_idx:400,running_loss:13.621421482563019
# epoch:4,batch_idx:400,running_loss:13.29786213696003
# epoch:4,batch_idx:400,running_loss:12.834350147247314
# epoch:4,batch_idx:400,running_loss:12.433557831943036
# epoch:4,batch_idx:400,running_loss:12.181541019380093
# epoch:4,batch_idx:400,running_loss:13.717326759696007
# epoch:4,batch_idx:400,running_loss:14.299431106746196
# epoch:4,batch_idx:400,running_loss:14.738833004832268
# epoch:4,batch_idx:400,running_loss:14.70532620817423
# epoch:4,batch_idx:400,running_loss:14.66574526578188
# epoch:4,batch_idx:400,running_loss:14.52168422356248
# epoch:4,batch_idx:400,running_loss:14.104031451940536
# epoch:4,batch_idx:400,running_loss:13.554997797608376
# epoch:4,batch_idx:400,running_loss:13.404381208717822
# epoch:4,batch_idx:400,running_loss:13.116245767772197
# epoch:4,batch_idx:400,running_loss:12.6229777520895
# epoch:4,batch_idx:400,running_loss:12.24369731515646
# epoch:4,batch_idx:400,running_loss:13.844696502685547
# epoch:4,batch_idx:400,running_loss:13.94931095302105
# epoch:4,batch_idx:400,running_loss:14.563329012393952
# epoch:4,batch_idx:400,running_loss:14.678820884525775
# epoch:4,batch_idx:400,running_loss:14.521220891773702
# epoch:4,batch_idx:400,running_loss:14.330148465931416
# epoch:4,batch_idx:400,running_loss:13.949428628981114
# epoch:4,batch_idx:400,running_loss:13.563579844236374
# epoch:4,batch_idx:400,running_loss:13.327215056419373
# epoch:4,batch_idx:400,running_loss:13.064323035776615
# epoch:4,batch_idx:400,running_loss:12.617897358238697
# epoch:4,batch_idx:400,running_loss:12.26773673593998
# ###epoch:4,train_loss:6.348957538604736
# epoch:5,batch_idx:400,running_loss:5.839404437020421
# epoch:5,batch_idx:400,running_loss:7.097959061414003
# epoch:5,batch_idx:400,running_loss:5.974972477927804
# epoch:5,batch_idx:400,running_loss:7.234732353389263
# epoch:5,batch_idx:400,running_loss:9.2390563210845
# epoch:5,batch_idx:400,running_loss:10.610347664058208
# epoch:5,batch_idx:400,running_loss:11.191916066259147
# epoch:5,batch_idx:400,running_loss:11.511005988717079
# epoch:5,batch_idx:400,running_loss:11.777958387210965
# epoch:5,batch_idx:400,running_loss:12.346332891955972
# epoch:5,batch_idx:400,running_loss:12.914520638287067
# epoch:5,batch_idx:400,running_loss:13.47696894288063
# epoch:5,batch_idx:400,running_loss:9.607671526372433
# epoch:5,batch_idx:400,running_loss:10.072356894910335
# epoch:5,batch_idx:400,running_loss:10.322921451330185
# epoch:5,batch_idx:400,running_loss:10.655389433503151
# epoch:5,batch_idx:400,running_loss:11.004420227110385
# epoch:5,batch_idx:400,running_loss:11.304034325629473
# epoch:5,batch_idx:400,running_loss:11.590735139399767
# epoch:5,batch_idx:400,running_loss:11.855901543796062
# epoch:5,batch_idx:400,running_loss:11.81080226033926
# epoch:5,batch_idx:400,running_loss:11.951029697656631
# epoch:5,batch_idx:400,running_loss:12.251500006094576
# epoch:5,batch_idx:400,running_loss:12.436236769631504
# epoch:5,batch_idx:400,running_loss:10.974366921782494
# epoch:5,batch_idx:400,running_loss:11.185655729323626
# epoch:5,batch_idx:400,running_loss:11.531512114405633
# epoch:5,batch_idx:400,running_loss:11.937686049044132
# epoch:5,batch_idx:400,running_loss:11.932663185298443
# epoch:5,batch_idx:400,running_loss:11.707421867996453
# epoch:5,batch_idx:400,running_loss:12.116413711756469
# epoch:5,batch_idx:400,running_loss:12.472344884574413
# epoch:5,batch_idx:400,running_loss:11.811349816024304
# epoch:5,batch_idx:400,running_loss:11.654621228128672
# epoch:5,batch_idx:400,running_loss:12.092446415051818
# epoch:5,batch_idx:400,running_loss:12.046481278091669
# epoch:5,batch_idx:400,running_loss:12.962631628513336
# epoch:5,batch_idx:400,running_loss:12.812573811858892
# epoch:5,batch_idx:400,running_loss:12.488226305693388
# epoch:5,batch_idx:400,running_loss:12.47994235560298
# epoch:5,batch_idx:400,running_loss:12.41056758224964
# epoch:5,batch_idx:400,running_loss:12.280746244788169
# epoch:5,batch_idx:400,running_loss:12.761345718055964
# epoch:5,batch_idx:400,running_loss:13.101363818496466
# epoch:5,batch_idx:400,running_loss:12.252297923415899
# epoch:5,batch_idx:400,running_loss:11.773656836152076
# epoch:5,batch_idx:400,running_loss:12.294935457706451
# epoch:5,batch_idx:400,running_loss:12.20751983627677
# epoch:5,batch_idx:400,running_loss:13.77931722432375
# epoch:5,batch_idx:400,running_loss:13.58797987177968
# epoch:5,batch_idx:400,running_loss:13.347092847526074
# epoch:5,batch_idx:400,running_loss:13.41107608616352
# epoch:5,batch_idx:400,running_loss:13.123980469480157
# epoch:5,batch_idx:400,running_loss:12.660039361268282
# epoch:5,batch_idx:400,running_loss:12.845986039936543
# epoch:5,batch_idx:400,running_loss:12.994414840936662
# epoch:5,batch_idx:400,running_loss:12.63218811839819
# epoch:5,batch_idx:400,running_loss:12.16230026602745
# epoch:5,batch_idx:400,running_loss:12.376639599353075
# epoch:5,batch_idx:400,running_loss:12.278981811851263
# epoch:5,batch_idx:400,running_loss:14.055536548495292
# epoch:5,batch_idx:400,running_loss:13.803999672830106
# epoch:5,batch_idx:400,running_loss:13.635278075933456
# epoch:5,batch_idx:400,running_loss:13.845358255654574
# epoch:5,batch_idx:400,running_loss:13.935456260591746
# epoch:5,batch_idx:400,running_loss:13.433070298433304
# epoch:5,batch_idx:400,running_loss:13.036491237729788
# epoch:5,batch_idx:400,running_loss:12.934833550453186
# epoch:5,batch_idx:400,running_loss:12.831314048171043
# epoch:5,batch_idx:400,running_loss:12.484537551403045
# epoch:5,batch_idx:400,running_loss:12.184297895282507
# epoch:5,batch_idx:400,running_loss:12.083044614046813
# epoch:5,batch_idx:400,running_loss:14.037116231620312
# epoch:5,batch_idx:400,running_loss:14.240483765751124
# epoch:5,batch_idx:400,running_loss:13.888117367997765
# epoch:5,batch_idx:400,running_loss:13.892429554983973
# epoch:5,batch_idx:400,running_loss:14.204773960411549
# epoch:5,batch_idx:400,running_loss:14.034223126620054
# epoch:5,batch_idx:400,running_loss:13.604518584311009
# epoch:5,batch_idx:400,running_loss:13.309238448292017
# epoch:5,batch_idx:400,running_loss:12.940280308574438
# epoch:5,batch_idx:400,running_loss:12.64387375086546
# epoch:5,batch_idx:400,running_loss:12.350039474070073
# epoch:5,batch_idx:400,running_loss:12.191322769224644
# epoch:5,batch_idx:400,running_loss:13.724824996590614
# epoch:5,batch_idx:400,running_loss:14.624072988331317
# epoch:5,batch_idx:400,running_loss:14.41833553262055
# epoch:5,batch_idx:400,running_loss:14.180322813019156
# epoch:5,batch_idx:400,running_loss:14.486535537093879
# epoch:5,batch_idx:400,running_loss:14.52987024664879
# epoch:5,batch_idx:400,running_loss:14.128940247744321
# epoch:5,batch_idx:400,running_loss:13.621421121358871
# epoch:5,batch_idx:400,running_loss:13.297862010598182
# epoch:5,batch_idx:400,running_loss:12.834350813031197
# epoch:5,batch_idx:400,running_loss:12.433557847440243
# epoch:5,batch_idx:400,running_loss:12.181541340053082
# epoch:5,batch_idx:400,running_loss:13.717327290773392
# epoch:5,batch_idx:400,running_loss:14.29943212211132
# epoch:5,batch_idx:400,running_loss:14.738832719475031
# epoch:5,batch_idx:400,running_loss:14.70532613441348
# epoch:5,batch_idx:400,running_loss:14.665745705217123
# epoch:5,batch_idx:400,running_loss:14.521685354560613
# epoch:5,batch_idx:400,running_loss:14.104030244350433
# epoch:5,batch_idx:400,running_loss:13.554997665286065
# epoch:5,batch_idx:400,running_loss:13.404381116330624
# epoch:5,batch_idx:400,running_loss:13.11624566733837
# epoch:5,batch_idx:400,running_loss:12.622978148758412
# epoch:5,batch_idx:400,running_loss:12.243696927428246
# epoch:5,batch_idx:400,running_loss:13.844696938991547
# epoch:5,batch_idx:400,running_loss:13.94931057959795
# epoch:5,batch_idx:400,running_loss:14.563328673541546
# epoch:5,batch_idx:400,running_loss:14.678820489048958
# epoch:5,batch_idx:400,running_loss:14.521221360266209
# epoch:5,batch_idx:400,running_loss:14.330148322582245
# epoch:5,batch_idx:400,running_loss:13.949428373277188
# epoch:5,batch_idx:400,running_loss:13.56357999742031
# epoch:5,batch_idx:400,running_loss:13.327214829325676
# epoch:5,batch_idx:400,running_loss:13.064322682917117
# epoch:5,batch_idx:400,running_loss:12.617896998524666
# epoch:5,batch_idx:400,running_loss:12.267736473679543
# ###epoch:5,train_loss:6.348957538604736
# epoch:6,batch_idx:400,running_loss:5.839404698982835
# epoch:6,batch_idx:400,running_loss:7.0979585362970825
# epoch:6,batch_idx:400,running_loss:5.974972345456481
# epoch:6,batch_idx:400,running_loss:7.234732511490583
# epoch:6,batch_idx:400,running_loss:9.239056398123502
# epoch:6,batch_idx:400,running_loss:10.610347669124604
# epoch:6,batch_idx:400,running_loss:11.191915647685528
# epoch:6,batch_idx:400,running_loss:11.511006361842156
# epoch:6,batch_idx:400,running_loss:11.77795850224793
# epoch:6,batch_idx:400,running_loss:12.34633311972022
# epoch:6,batch_idx:400,running_loss:12.914520666003227
# epoch:6,batch_idx:400,running_loss:13.476968960464001
# epoch:6,batch_idx:400,running_loss:9.607671227455139
# epoch:6,batch_idx:400,running_loss:10.072356590926647
# epoch:6,batch_idx:400,running_loss:10.322921673953534
# epoch:6,batch_idx:400,running_loss:10.65538918301463
# epoch:6,batch_idx:400,running_loss:11.004419614523648
# epoch:6,batch_idx:400,running_loss:11.304034268260002
# epoch:6,batch_idx:400,running_loss:11.590734616219997
# epoch:6,batch_idx:400,running_loss:11.85590117752552
# epoch:6,batch_idx:400,running_loss:11.810802803635598
# epoch:6,batch_idx:400,running_loss:11.951029920354486
# epoch:6,batch_idx:400,running_loss:12.251499564424158
# epoch:6,batch_idx:400,running_loss:12.436237134113908
# epoch:6,batch_idx:400,running_loss:10.974366925507784
# epoch:6,batch_idx:400,running_loss:11.185655745416879
# epoch:6,batch_idx:400,running_loss:11.53151199951768
# epoch:6,batch_idx:400,running_loss:11.937686184197664
# epoch:6,batch_idx:400,running_loss:11.932663093656302
# epoch:6,batch_idx:400,running_loss:11.707421854585409
# epoch:6,batch_idx:400,running_loss:12.116413591504097
# epoch:6,batch_idx:400,running_loss:12.472344742715359
# epoch:6,batch_idx:400,running_loss:11.811349909156561
# epoch:6,batch_idx:400,running_loss:11.654621373713017
# epoch:6,batch_idx:400,running_loss:12.092445997223258
# epoch:6,batch_idx:400,running_loss:12.04648090057075
# epoch:6,batch_idx:400,running_loss:12.962631865143775
# epoch:6,batch_idx:400,running_loss:12.812574345469475
# epoch:6,batch_idx:400,running_loss:12.488226436376571
# epoch:6,batch_idx:400,running_loss:12.479941928237677
# epoch:6,batch_idx:400,running_loss:12.410567664653064
# epoch:6,batch_idx:400,running_loss:12.280746743977069
# epoch:6,batch_idx:400,running_loss:12.76134551718831
# epoch:6,batch_idx:400,running_loss:13.10136381521821
# epoch:6,batch_idx:400,running_loss:12.252298197448253
# epoch:6,batch_idx:400,running_loss:11.773656976670027
# epoch:6,batch_idx:400,running_loss:12.294935529530049
# epoch:6,batch_idx:400,running_loss:12.20751964211464
# epoch:6,batch_idx:400,running_loss:13.779318323731422
# epoch:6,batch_idx:400,running_loss:13.587980269938708
# epoch:6,batch_idx:400,running_loss:13.347092064470052
# epoch:6,batch_idx:400,running_loss:13.411074917986989
# epoch:6,batch_idx:400,running_loss:13.123981556966902
# epoch:6,batch_idx:400,running_loss:12.660039872676133
# epoch:6,batch_idx:400,running_loss:12.845985838174819
# epoch:6,batch_idx:400,running_loss:12.99441494718194
# epoch:6,batch_idx:400,running_loss:12.632188523113728
# epoch:6,batch_idx:400,running_loss:12.162300421893598
# epoch:6,batch_idx:400,running_loss:12.376639346927405
# epoch:6,batch_idx:400,running_loss:12.278981727212667
# epoch:6,batch_idx:400,running_loss:14.055536452829838
# epoch:6,batch_idx:400,running_loss:13.804000049978495
# epoch:6,batch_idx:400,running_loss:13.635279414579273
# epoch:6,batch_idx:400,running_loss:13.845357310324907
# epoch:6,batch_idx:400,running_loss:13.93545543730259
# epoch:6,batch_idx:400,running_loss:13.433070548474788
# epoch:6,batch_idx:400,running_loss:13.036491214632989
# epoch:6,batch_idx:400,running_loss:12.934834078103304
# epoch:6,batch_idx:400,running_loss:12.831313357502221
# epoch:6,batch_idx:400,running_loss:12.48453795671463
# epoch:6,batch_idx:400,running_loss:12.184298286288977
# epoch:6,batch_idx:400,running_loss:12.083044427782298
# epoch:6,batch_idx:400,running_loss:14.037115978598594
# epoch:6,batch_idx:400,running_loss:14.240484487116337
# epoch:6,batch_idx:400,running_loss:13.888117987439037
# epoch:6,batch_idx:400,running_loss:13.892432379797102
# epoch:6,batch_idx:400,running_loss:14.204772146046162
# epoch:6,batch_idx:400,running_loss:14.0342233414948
# epoch:6,batch_idx:400,running_loss:13.604518333151937
# epoch:6,batch_idx:400,running_loss:13.309238440543414
# epoch:6,batch_idx:400,running_loss:12.940280070453882
# epoch:6,batch_idx:400,running_loss:12.643873193860054
# epoch:6,batch_idx:400,running_loss:12.35003863632679
# epoch:6,batch_idx:400,running_loss:12.191323612332344
# epoch:6,batch_idx:400,running_loss:13.724825270473957
# epoch:6,batch_idx:400,running_loss:14.624073426127433
# epoch:6,batch_idx:400,running_loss:14.418336019217968
# epoch:6,batch_idx:400,running_loss:14.180322095155717
# epoch:6,batch_idx:400,running_loss:14.486536372154951
# epoch:6,batch_idx:400,running_loss:14.529871111661196
# epoch:6,batch_idx:400,running_loss:14.128940530717372
# epoch:6,batch_idx:400,running_loss:13.621421385854482
# epoch:6,batch_idx:400,running_loss:13.297861823439598
# epoch:6,batch_idx:400,running_loss:12.834350879192352
# epoch:6,batch_idx:400,running_loss:12.433558066785336
# epoch:6,batch_idx:400,running_loss:12.18154086947441
# epoch:6,batch_idx:400,running_loss:13.717327298223973
# epoch:6,batch_idx:400,running_loss:14.299431994855404
# epoch:6,batch_idx:400,running_loss:14.738833333104848
# epoch:6,batch_idx:400,running_loss:14.705326064676047
# epoch:6,batch_idx:400,running_loss:14.665745402276515
# epoch:6,batch_idx:400,running_loss:14.521684954613447
# epoch:6,batch_idx:400,running_loss:14.1040305519104
# epoch:6,batch_idx:400,running_loss:13.554997459352016
# epoch:6,batch_idx:400,running_loss:13.404381051659584
# epoch:6,batch_idx:400,running_loss:13.116245740354062
# epoch:6,batch_idx:400,running_loss:12.62297800630331
# epoch:6,batch_idx:400,running_loss:12.243697457313537
# epoch:6,batch_idx:400,running_loss:13.844696603417397
# epoch:6,batch_idx:400,running_loss:13.949310821294784
# epoch:6,batch_idx:400,running_loss:14.563328337073326
# epoch:6,batch_idx:400,running_loss:14.67881998538971
# epoch:6,batch_idx:400,running_loss:14.521221374124288
# epoch:6,batch_idx:400,running_loss:14.330148799419403
# epoch:6,batch_idx:400,running_loss:13.949428695142268
# epoch:6,batch_idx:400,running_loss:13.563580244779587
# epoch:6,batch_idx:400,running_loss:13.327215533256531
# epoch:6,batch_idx:400,running_loss:13.064322431385516
# epoch:6,batch_idx:400,running_loss:12.617897512018681
# epoch:6,batch_idx:400,running_loss:12.267737293243409
# ###epoch:6,train_loss:6.348955154418945
# epoch:7,batch_idx:400,running_loss:5.839404563009739
# epoch:7,batch_idx:400,running_loss:7.097958891540766
# epoch:7,batch_idx:400,running_loss:5.974972275644541
# epoch:7,batch_idx:400,running_loss:7.234732003957033
# epoch:7,batch_idx:400,running_loss:9.23905651062727
# epoch:7,batch_idx:400,running_loss:10.610347383022308
# epoch:7,batch_idx:400,running_loss:11.191915772855282
# epoch:7,batch_idx:400,running_loss:11.511006548404694
# epoch:7,batch_idx:400,running_loss:11.777958160415292
# epoch:7,batch_idx:400,running_loss:12.34633268147707
# epoch:7,batch_idx:400,running_loss:12.914521030634642
# epoch:7,batch_idx:400,running_loss:13.47696891516447
# epoch:7,batch_idx:400,running_loss:9.607671296298504
# epoch:7,batch_idx:400,running_loss:10.072356684803962
# epoch:7,batch_idx:400,running_loss:10.322921651005744
# epoch:7,batch_idx:400,running_loss:10.6553896266222
# epoch:7,batch_idx:400,running_loss:11.004419848322868
# epoch:7,batch_idx:400,running_loss:11.304034429043531
# epoch:7,batch_idx:400,running_loss:11.590734964311123
# epoch:7,batch_idx:400,running_loss:11.855901269614696
# epoch:7,batch_idx:400,running_loss:11.810802673101426
# epoch:7,batch_idx:400,running_loss:11.95103044345975
# epoch:7,batch_idx:400,running_loss:12.251499824747443
# epoch:7,batch_idx:400,running_loss:12.436236955076456
# epoch:7,batch_idx:400,running_loss:10.974366675764323
# epoch:7,batch_idx:400,running_loss:11.185656046718359
# epoch:7,batch_idx:400,running_loss:11.531512742936611
# epoch:7,batch_idx:400,running_loss:11.937686140239238
# epoch:7,batch_idx:400,running_loss:11.932663388699293
# epoch:7,batch_idx:400,running_loss:11.707421656399966
# epoch:7,batch_idx:400,running_loss:12.116413538753987
# epoch:7,batch_idx:400,running_loss:12.472344937920571
# epoch:7,batch_idx:400,running_loss:11.81134974166751
# epoch:7,batch_idx:400,running_loss:11.654621152430773
# epoch:7,batch_idx:400,running_loss:12.09244665890932
# epoch:7,batch_idx:400,running_loss:12.046480977833271
# epoch:7,batch_idx:400,running_loss:12.962631044983864
# epoch:7,batch_idx:400,running_loss:12.81257382467389
# epoch:7,batch_idx:400,running_loss:12.488225966393948
# epoch:7,batch_idx:400,running_loss:12.47994250640273
# epoch:7,batch_idx:400,running_loss:12.410567557513714
# epoch:7,batch_idx:400,running_loss:12.280747214853763
# epoch:7,batch_idx:400,running_loss:12.761345561295748
# epoch:7,batch_idx:400,running_loss:13.101363704204559
# epoch:7,batch_idx:400,running_loss:12.252298219650983
# epoch:7,batch_idx:400,running_loss:11.773657076209783
# epoch:7,batch_idx:400,running_loss:12.294935405552387
# epoch:7,batch_idx:400,running_loss:12.207519664466382
# epoch:7,batch_idx:400,running_loss:13.779318751096726
# epoch:7,batch_idx:400,running_loss:13.587980091124773
# epoch:7,batch_idx:400,running_loss:13.347091946452856
# epoch:7,batch_idx:400,running_loss:13.411075577810406
# epoch:7,batch_idx:400,running_loss:13.123981227651239
# epoch:7,batch_idx:400,running_loss:12.66003971800208
# epoch:7,batch_idx:400,running_loss:12.845985812544823
# epoch:7,batch_idx:400,running_loss:12.994414937347173
# epoch:7,batch_idx:400,running_loss:12.632188114821911
# epoch:7,batch_idx:400,running_loss:12.162300445437431
# epoch:7,batch_idx:400,running_loss:12.376639673560858
# epoch:7,batch_idx:400,running_loss:12.278982215225696
# epoch:7,batch_idx:400,running_loss:14.05553655833006
# epoch:7,batch_idx:400,running_loss:13.80400040537119
# epoch:7,batch_idx:400,running_loss:13.635279150381685
# epoch:7,batch_idx:400,running_loss:13.845356704294682
# epoch:7,batch_idx:400,running_loss:13.935456131845713
# epoch:7,batch_idx:400,running_loss:13.433070454895496
# epoch:7,batch_idx:400,running_loss:13.036490021198988
# epoch:7,batch_idx:400,running_loss:12.934833747148513
# epoch:7,batch_idx:400,running_loss:12.831313475370408
# epoch:7,batch_idx:400,running_loss:12.484538379013538
# epoch:7,batch_idx:400,running_loss:12.18429825231433
# epoch:7,batch_idx:400,running_loss:12.083044260293246
# epoch:7,batch_idx:400,running_loss:14.037115019857884
# epoch:7,batch_idx:400,running_loss:14.24048446431756
# epoch:7,batch_idx:400,running_loss:13.888117617741226
# epoch:7,batch_idx:400,running_loss:13.892428974583744
# epoch:7,batch_idx:400,running_loss:14.204772335737944
# epoch:7,batch_idx:400,running_loss:14.034223240315914
# epoch:7,batch_idx:400,running_loss:13.60451788276434
# epoch:7,batch_idx:400,running_loss:13.309238589257001
# epoch:7,batch_idx:400,running_loss:12.940280358493329
# epoch:7,batch_idx:400,running_loss:12.643873921632768
# epoch:7,batch_idx:400,running_loss:12.35003986120224
# epoch:7,batch_idx:400,running_loss:12.19132258862257
# epoch:7,batch_idx:400,running_loss:13.72482569128275
# epoch:7,batch_idx:400,running_loss:14.624073341786861
# epoch:7,batch_idx:400,running_loss:14.418337438628077
# epoch:7,batch_idx:400,running_loss:14.180322047770023
# epoch:7,batch_idx:400,running_loss:14.486536690443755
# epoch:7,batch_idx:400,running_loss:14.529873698204756
# epoch:7,batch_idx:400,running_loss:14.128940710425377
# epoch:7,batch_idx:400,running_loss:13.621421217173339
# epoch:7,batch_idx:400,running_loss:13.297862327694894
# epoch:7,batch_idx:400,running_loss:12.834350707828998
# epoch:7,batch_idx:400,running_loss:12.433557437062264
# epoch:7,batch_idx:400,running_loss:12.181541020572185
# epoch:7,batch_idx:400,running_loss:13.717326920330525
# epoch:7,batch_idx:400,running_loss:14.29943169504404
# epoch:7,batch_idx:400,running_loss:14.738832468241453
# epoch:7,batch_idx:400,running_loss:14.705326460301876
# epoch:7,batch_idx:400,running_loss:14.665745117962361
# epoch:7,batch_idx:400,running_loss:14.521684552431106
# epoch:7,batch_idx:400,running_loss:14.10403020977974
# epoch:7,batch_idx:400,running_loss:13.554997499585152
# epoch:7,batch_idx:400,running_loss:13.40438103556633
# epoch:7,batch_idx:400,running_loss:13.116245229244232
# epoch:7,batch_idx:400,running_loss:12.622978026866912
# epoch:7,batch_idx:400,running_loss:12.243697192370892
# epoch:7,batch_idx:400,running_loss:13.844696724712849
# epoch:7,batch_idx:400,running_loss:13.949310924112797
# epoch:7,batch_idx:400,running_loss:14.563328586518764
# epoch:7,batch_idx:400,running_loss:14.678821858614683
# epoch:7,batch_idx:400,running_loss:14.52122159332037
# epoch:7,batch_idx:400,running_loss:14.33014799118042
# epoch:7,batch_idx:400,running_loss:13.949428486824036
# epoch:7,batch_idx:400,running_loss:13.563580068051815
# epoch:7,batch_idx:400,running_loss:13.32721518278122
# epoch:7,batch_idx:400,running_loss:13.064322399497032
# epoch:7,batch_idx:400,running_loss:12.617897462844848
# epoch:7,batch_idx:400,running_loss:12.267736848592758
# ###epoch:7,train_loss:6.348955154418945
# epoch:8,batch_idx:400,running_loss:5.839404481351376
# epoch:8,batch_idx:400,running_loss:7.097959053069353
# epoch:8,batch_idx:400,running_loss:5.974971977248788
# epoch:8,batch_idx:400,running_loss:7.234732023328543
# epoch:8,batch_idx:400,running_loss:9.23905636459589
# epoch:8,batch_idx:400,running_loss:10.610347614586352
# epoch:8,batch_idx:400,running_loss:11.191915989220142
# epoch:8,batch_idx:400,running_loss:11.511005929410457
# epoch:8,batch_idx:400,running_loss:11.777958298400044
# epoch:8,batch_idx:400,running_loss:12.346332915723323
# epoch:8,batch_idx:400,running_loss:12.914520406723023
# epoch:8,batch_idx:400,running_loss:13.476969127058982
# epoch:8,batch_idx:400,running_loss:9.607671431601048
# epoch:8,batch_idx:400,running_loss:10.072357245385646
# epoch:8,batch_idx:400,running_loss:10.322921737134457
# epoch:8,batch_idx:400,running_loss:10.655389102846383
# epoch:8,batch_idx:400,running_loss:11.00441981613636
# epoch:8,batch_idx:400,running_loss:11.304034104645252
# epoch:8,batch_idx:400,running_loss:11.590734710544348
# epoch:8,batch_idx:400,running_loss:11.855901523679496
# epoch:8,batch_idx:400,running_loss:11.810802793502807
# epoch:8,batch_idx:400,running_loss:11.951029956787824
# epoch:8,batch_idx:400,running_loss:12.251499847099184
# epoch:8,batch_idx:400,running_loss:12.436236563026904
# epoch:8,batch_idx:400,running_loss:10.974366766512395
# epoch:8,batch_idx:400,running_loss:11.185656063258648
# epoch:8,batch_idx:400,running_loss:11.531513078212738
# epoch:8,batch_idx:400,running_loss:11.937686145156622
# epoch:8,batch_idx:400,running_loss:11.932663208693265
# epoch:8,batch_idx:400,running_loss:11.707421737760306
# epoch:8,batch_idx:400,running_loss:12.116412947773933
# epoch:8,batch_idx:400,running_loss:12.472344814389944
# epoch:8,batch_idx:400,running_loss:11.811349975317716
# epoch:8,batch_idx:400,running_loss:11.654621083140373
# epoch:8,batch_idx:400,running_loss:12.092446189150214
# epoch:8,batch_idx:400,running_loss:12.04648121073842
# epoch:8,batch_idx:400,running_loss:12.962631684541702
# epoch:8,batch_idx:400,running_loss:12.812574109584093
# epoch:8,batch_idx:400,running_loss:12.488226189911366
# epoch:8,batch_idx:400,running_loss:12.47994183987379
# epoch:8,batch_idx:400,running_loss:12.41056671604514
# epoch:8,batch_idx:400,running_loss:12.280747515410185
# epoch:8,batch_idx:400,running_loss:12.761345471143722
# epoch:8,batch_idx:400,running_loss:13.101364075690508
# epoch:8,batch_idx:400,running_loss:12.252298135459423
# epoch:8,batch_idx:400,running_loss:11.773657281845807
# epoch:8,batch_idx:400,running_loss:12.294935286864638
# ...
# epoch:8,batch_idx:400,running_loss:12.934833652675152
# epoch:8,batch_idx:400,running_loss:12.8313132353127
# epoch:8,batch_idx:400,running_loss:12.484538140892983
# epoch:8,batch_idx:400,running_loss:12.184298729151488
# epoch:8,batch_idx:400,running_loss:12.083044770359994
# epoch:8,batch_idx:400,running_loss:14.037115927636624
# epoch:8,batch_idx:400,running_loss:14.24048404097557
# epoch:8,batch_idx:400,running_loss:13.888116433098912
# epoch:8,batch_idx:400,running_loss:13.89242988333106
# epoch:8,batch_idx:400,running_loss:14.20477276608348
# epoch:8,batch_idx:400,running_loss:14.03422347471118
# epoch:8,batch_idx:400,running_loss:13.604517387747764
# epoch:8,batch_idx:400,running_loss:13.309238520115613
# epoch:8,batch_idx:400,running_loss:12.940280062258244
# epoch:8,batch_idx:400,running_loss:12.643873239457607
# epoch:8,batch_idx:400,running_loss:12.35003842175007
# epoch:8,batch_idx:400,running_loss:12.191322436630726
# epoch:8,batch_idx:400,running_loss:13.72482650846243
# epoch:8,batch_idx:400,running_loss:14.624073451459408
# epoch:8,batch_idx:400,running_loss:14.418336881250143
# epoch:8,batch_idx:400,running_loss:14.180320793539286
# epoch:8,batch_idx:400,running_loss:14.486535475999117
# epoch:8,batch_idx:400,running_loss:14.529870790541173
# epoch:8,batch_idx:400,running_loss:14.128940354436637
# epoch:8,batch_idx:400,running_loss:13.621421229541301
# epoch:8,batch_idx:400,running_loss:13.297862089276315
# epoch:8,batch_idx:400,running_loss:12.834350467026233
# epoch:8,batch_idx:400,running_loss:12.433557934165002
# epoch:8,batch_idx:400,running_loss:12.18154069662094
# epoch:8,batch_idx:400,running_loss:13.717327026426792
# epoch:8,batch_idx:400,running_loss:14.299431709945202
# epoch:8,batch_idx:400,running_loss:14.738832810074092
# epoch:8,batch_idx:400,running_loss:14.705328008532524
# epoch:8,batch_idx:400,running_loss:14.665746110379695
# epoch:8,batch_idx:400,running_loss:14.52168471828103
# epoch:8,batch_idx:400,running_loss:14.104030384719373
# epoch:8,batch_idx:400,running_loss:13.554997341036797
# epoch:8,batch_idx:400,running_loss:13.404381076991559
# epoch:8,batch_idx:400,running_loss:13.116245534420013
# epoch:8,batch_idx:400,running_loss:12.622978001832962
# epoch:8,batch_idx:400,running_loss:12.243697214722634
# epoch:8,batch_idx:400,running_loss:13.844696314632893
# epoch:8,batch_idx:400,running_loss:13.949310725331307
# epoch:8,batch_idx:400,running_loss:14.56332856297493
# epoch:8,batch_idx:400,running_loss:14.678820050954819
# epoch:8,batch_idx:400,running_loss:14.521220635771751
# epoch:8,batch_idx:400,running_loss:14.33014870017767
# epoch:8,batch_idx:400,running_loss:13.949428808689117
# epoch:8,batch_idx:400,running_loss:13.563579667806625
# epoch:8,batch_idx:400,running_loss:13.327215186059474
# epoch:8,batch_idx:400,running_loss:13.064322271347045
# epoch:8,batch_idx:400,running_loss:12.61789722532034
# epoch:8,batch_idx:400,running_loss:12.267737228572368
# ###epoch:8,train_loss:6.348955154418945
# epoch:9,batch_idx:400,running_loss:5.839404692426324
# epoch:9,batch_idx:400,running_loss:7.0979592122137545
# epoch:9,batch_idx:400,running_loss:5.97497221916914
# epoch:9,batch_idx:400,running_loss:7.234732090681791
# epoch:9,batch_idx:400,running_loss:9.23905649393797
# epoch:9,batch_idx:400,running_loss:10.610347565114498
# epoch:9,batch_idx:400,running_loss:11.19191596493125
# epoch:9,batch_idx:400,running_loss:11.511005973815918
# epoch:9,batch_idx:400,running_loss:11.77795839317143
# epoch:9,batch_idx:400,running_loss:12.346332591325044
# epoch:9,batch_idx:400,running_loss:12.914520589113236
# epoch:9,batch_idx:400,running_loss:13.476968775987626
# epoch:9,batch_idx:400,running_loss:9.607671431601048
# epoch:9,batch_idx:400,running_loss:10.072356979548932
# epoch:9,batch_idx:400,running_loss:10.322921812832355
# epoch:9,batch_idx:400,running_loss:10.655389751791954
# epoch:9,batch_idx:400,running_loss:11.004419722557067
# epoch:9,batch_idx:400,running_loss:11.304034329503775
# epoch:9,batch_idx:400,running_loss:11.590735033005476
# epoch:9,batch_idx:400,running_loss:11.85590131521225
# epoch:9,batch_idx:400,running_loss:11.81080224737525
# epoch:9,batch_idx:400,running_loss:11.95102991886437
# epoch:9,batch_idx:400,running_loss:12.251499935910106
# epoch:9,batch_idx:400,running_loss:12.436236498355866
# epoch:9,batch_idx:400,running_loss:10.97436646565795
# epoch:9,batch_idx:400,running_loss:11.185656250864268
# epoch:9,batch_idx:400,running_loss:11.531512930840254
# epoch:9,batch_idx:400,running_loss:11.937685950547456
# epoch:9,batch_idx:400,running_loss:11.932662790864706
# epoch:9,batch_idx:400,running_loss:11.707422028481961
# epoch:9,batch_idx:400,running_loss:12.116413415521384
# epoch:9,batch_idx:400,running_loss:12.472344972640276
# epoch:9,batch_idx:400,running_loss:11.811350269317627
# epoch:9,batch_idx:400,running_loss:11.65462143242359
# epoch:9,batch_idx:400,running_loss:12.092446234598755
# epoch:9,batch_idx:400,running_loss:12.046481601893902
# epoch:9,batch_idx:400,running_loss:12.962632063627243
# epoch:9,batch_idx:400,running_loss:12.812574044913054
# epoch:9,batch_idx:400,running_loss:12.488226148933173
# epoch:9,batch_idx:400,running_loss:12.479942684918642
# epoch:9,batch_idx:400,running_loss:12.410566643252968
# epoch:9,batch_idx:400,running_loss:12.28074660718441
# epoch:9,batch_idx:400,running_loss:12.76134546071291
# epoch:9,batch_idx:400,running_loss:13.101364023387433
# epoch:9,batch_idx:400,running_loss:12.252298200726509
# epoch:9,batch_idx:400,running_loss:11.77365713790059
# epoch:9,batch_idx:400,running_loss:12.294935326874256
# epoch:9,batch_idx:400,running_loss:12.207520103305578
# epoch:9,batch_idx:400,running_loss:13.779317519962788
# epoch:9,batch_idx:400,running_loss:13.587980392426253
# epoch:9,batch_idx:400,running_loss:13.34709293961525
# epoch:9,batch_idx:400,running_loss:13.411076256930828
# epoch:9,batch_idx:400,running_loss:13.123981512486935
# epoch:9,batch_idx:400,running_loss:12.660038946568966
# epoch:9,batch_idx:400,running_loss:12.845985673218966
# epoch:9,batch_idx:400,running_loss:12.994415127635001
# epoch:9,batch_idx:400,running_loss:12.632188379764557
# epoch:9,batch_idx:400,running_loss:12.162300020605326
# epoch:9,batch_idx:400,running_loss:12.376639614850284
# epoch:9,batch_idx:400,running_loss:12.278982190191746
# epoch:9,batch_idx:400,running_loss:14.055535955429077
# epoch:9,batch_idx:400,running_loss:13.803999532759189
# epoch:9,batch_idx:400,running_loss:13.635278385877609
# epoch:9,batch_idx:400,running_loss:13.845357146710157
# epoch:9,batch_idx:400,running_loss:13.935456232726574
# epoch:9,batch_idx:400,running_loss:13.433070904612542
# epoch:9,batch_idx:400,running_loss:13.036491606235504
# epoch:9,batch_idx:400,running_loss:12.934833668768405
# epoch:9,batch_idx:400,running_loss:12.831313228160143
# epoch:9,batch_idx:400,running_loss:12.484538030624389
# epoch:9,batch_idx:400,running_loss:12.184298275858163
# epoch:9,batch_idx:400,running_loss:12.083044625371695
# epoch:9,batch_idx:400,running_loss:14.037115588784218
# epoch:9,batch_idx:400,running_loss:14.240484393090009
# epoch:9,batch_idx:400,running_loss:13.888117193058132
# epoch:9,batch_idx:400,running_loss:13.892428539842367
# epoch:9,batch_idx:400,running_loss:14.204774682074785
# epoch:9,batch_idx:400,running_loss:14.034223335385322
# epoch:9,batch_idx:400,running_loss:13.604517656937242
# epoch:9,batch_idx:400,running_loss:13.309238743036985
# epoch:9,batch_idx:400,running_loss:12.940280421376228
# epoch:9,batch_idx:400,running_loss:12.643872494101524
# epoch:9,batch_idx:400,running_loss:12.350039214789867
# epoch:9,batch_idx:400,running_loss:12.19132381528616
# epoch:9,batch_idx:400,running_loss:13.724825577735901
# epoch:9,batch_idx:400,running_loss:14.6240733268857
# epoch:9,batch_idx:400,running_loss:14.418335612639785
# epoch:9,batch_idx:400,running_loss:14.180322723016143
# epoch:9,batch_idx:400,running_loss:14.486536335200071
# epoch:9,batch_idx:400,running_loss:14.529873063117266
# epoch:9,batch_idx:400,running_loss:14.128940268307923
# epoch:9,batch_idx:400,running_loss:13.621421262025834
# epoch:9,batch_idx:400,running_loss:13.29786202698946
# epoch:9,batch_idx:400,running_loss:12.834350972175598
# epoch:9,batch_idx:400,running_loss:12.433557552397252
# epoch:9,batch_idx:400,running_loss:12.181541783511639
# epoch:9,batch_idx:400,running_loss:13.717326898872852
# epoch:9,batch_idx:400,running_loss:14.299431332349776
# epoch:9,batch_idx:400,running_loss:14.73883318066597
# epoch:9,batch_idx:400,running_loss:14.705326420515776
# epoch:9,batch_idx:400,running_loss:14.665745342075825
# epoch:9,batch_idx:400,running_loss:14.52168372437358
# epoch:9,batch_idx:400,running_loss:14.104030859470367
# epoch:9,batch_idx:400,running_loss:13.5549977093935
# epoch:9,batch_idx:400,running_loss:13.404381222724915
# epoch:9,batch_idx:400,running_loss:13.116246756613254
# epoch:9,batch_idx:400,running_loss:12.622978058755399
# epoch:9,batch_idx:400,running_loss:12.243697255253792
# epoch:9,batch_idx:400,running_loss:13.844696667194366
# epoch:9,batch_idx:400,running_loss:13.949311424195766
# epoch:9,batch_idx:400,running_loss:14.563328721821309
# epoch:9,batch_idx:400,running_loss:14.67881999269128
# epoch:9,batch_idx:400,running_loss:14.521221272945404
# epoch:9,batch_idx:400,running_loss:14.330148276686668
# epoch:9,batch_idx:400,running_loss:13.949428369998932
# epoch:9,batch_idx:400,running_loss:13.563579664528369
# epoch:9,batch_idx:400,running_loss:13.3272152402997
# epoch:9,batch_idx:400,running_loss:13.064322402477265
# epoch:9,batch_idx:400,running_loss:12.617897289693355
# epoch:9,batch_idx:400,running_loss:12.267736485302448
# ###epoch:9,train_loss:6.348955154418945
# epoch:10,batch_idx:400,running_loss:5.83940444290638
# epoch:10,batch_idx:400,running_loss:7.097959129363298
# epoch:10,batch_idx:400,running_loss:5.974972405210138
# epoch:10,batch_idx:400,running_loss:7.234731988161802
# epoch:10,batch_idx:400,running_loss:9.239056542217732
# epoch:10,batch_idx:400,running_loss:10.610347394645213
# epoch:10,batch_idx:400,running_loss:11.191915826052428
# epoch:10,batch_idx:400,running_loss:11.51100586593151
# epoch:10,batch_idx:400,running_loss:11.777958499267697
# epoch:10,batch_idx:400,running_loss:12.34633277580142
# epoch:10,batch_idx:400,running_loss:12.914520801007747
# epoch:10,batch_idx:400,running_loss:13.476969272792338
# epoch:10,batch_idx:400,running_loss:9.607671328186989
# epoch:10,batch_idx:400,running_loss:10.072357167899609
# epoch:10,batch_idx:400,running_loss:10.322921500504016
# epoch:10,batch_idx:400,running_loss:10.655389252305032
# epoch:10,batch_idx:400,running_loss:11.004420002251864
# epoch:10,batch_idx:400,running_loss:11.30403419494629
# epoch:10,batch_idx:400,running_loss:11.590734843611717
# epoch:10,batch_idx:400,running_loss:11.855901179015637
# epoch:10,batch_idx:400,running_loss:11.810802499353885
# epoch:10,batch_idx:400,running_loss:11.951030263379216
# epoch:10,batch_idx:400,running_loss:12.251499677076936
# epoch:10,batch_idx:400,running_loss:12.43623695448041
# epoch:10,batch_idx:400,running_loss:10.974366726726293
# epoch:10,batch_idx:400,running_loss:11.185656095743179
# epoch:10,batch_idx:400,running_loss:11.531512631177902
# epoch:10,batch_idx:400,running_loss:11.937686207145452
# epoch:10,batch_idx:400,running_loss:11.932662851065396
# epoch:10,batch_idx:400,running_loss:11.707421991974115
# epoch:10,batch_idx:400,running_loss:12.11641345486045
# epoch:10,batch_idx:400,running_loss:12.472344895005227
# epoch:10,batch_idx:400,running_loss:11.811349686384201
# epoch:10,batch_idx:400,running_loss:11.65462133347988
# epoch:10,batch_idx:400,running_loss:12.092446565553546
# epoch:10,batch_idx:400,running_loss:12.046481253802776
# epoch:10,batch_idx:400,running_loss:12.962631323039531
# epoch:10,batch_idx:400,running_loss:12.81257378473878
# epoch:10,batch_idx:400,running_loss:12.488226239234208
# epoch:10,batch_idx:400,running_loss:12.479941838234662
# epoch:10,batch_idx:400,running_loss:12.410567613691091
# epoch:10,batch_idx:400,running_loss:12.280746725201606
# epoch:10,batch_idx:400,running_loss:12.761345439106226
# epoch:10,batch_idx:400,running_loss:13.101363867819309
# epoch:10,batch_idx:400,running_loss:12.252298120856285
# epoch:10,batch_idx:400,running_loss:11.773657162338495
# epoch:10,batch_idx:400,running_loss:12.294935626983643
# epoch:10,batch_idx:400,running_loss:12.207519903481007
# epoch:10,batch_idx:400,running_loss:13.779318190515042
# epoch:10,batch_idx:400,running_loss:13.587979686111211
# epoch:10,batch_idx:400,running_loss:13.347092796713113
# epoch:10,batch_idx:400,running_loss:13.411076306030154
# epoch:10,batch_idx:400,running_loss:13.12398148059845
# epoch:10,batch_idx:400,running_loss:12.66003884345293
# epoch:10,batch_idx:400,running_loss:12.845985664725303
# epoch:10,batch_idx:400,running_loss:12.994414899796247
# epoch:10,batch_idx:400,running_loss:12.632188161015511
# epoch:10,batch_idx:400,running_loss:12.162299874424935
# epoch:10,batch_idx:400,running_loss:12.376639342457056
# epoch:10,batch_idx:400,running_loss:12.27898231074214
# epoch:10,batch_idx:400,running_loss:14.055537300407886
# epoch:10,batch_idx:400,running_loss:13.803999791592359
# epoch:10,batch_idx:400,running_loss:13.635278768911958
# epoch:10,batch_idx:400,running_loss:13.845355616360903
# epoch:10,batch_idx:400,running_loss:13.93545572295785
# epoch:10,batch_idx:400,running_loss:13.43307091653347
# epoch:10,batch_idx:400,running_loss:13.036491091176867
# epoch:10,batch_idx:400,running_loss:12.934833429902792
# epoch:10,batch_idx:400,running_loss:12.83131317332387
# epoch:10,batch_idx:400,running_loss:12.484538239687682
# epoch:10,batch_idx:400,running_loss:12.184298292845488
# epoch:10,batch_idx:400,running_loss:12.08304500952363
# epoch:10,batch_idx:400,running_loss:14.037115632593633
# epoch:10,batch_idx:400,running_loss:14.24048391059041
# epoch:10,batch_idx:400,running_loss:13.888118008747696
# epoch:10,batch_idx:400,running_loss:13.892428878694773
# epoch:10,batch_idx:400,running_loss:14.20477259337902
# epoch:10,batch_idx:400,running_loss:14.03422343045473
# epoch:10,batch_idx:400,running_loss:13.604517669677735
# epoch:10,batch_idx:400,running_loss:13.30923825547099
# epoch:10,batch_idx:400,running_loss:12.940279996097088
# epoch:10,batch_idx:400,running_loss:12.643873486816883
# epoch:10,batch_idx:400,running_loss:12.350038554370403
# epoch:10,batch_idx:400,running_loss:12.191322473883629
# epoch:10,batch_idx:400,running_loss:13.724826168119908
# epoch:10,batch_idx:400,running_loss:14.624073188602924
# epoch:10,batch_idx:400,running_loss:14.418337178975344
# epoch:10,batch_idx:400,running_loss:14.180321838632226
# epoch:10,batch_idx:400,running_loss:14.486536605507135
# epoch:10,batch_idx:400,running_loss:14.529872246086597
# epoch:10,batch_idx:400,running_loss:14.128940244168042
# epoch:10,batch_idx:400,running_loss:13.621421447098255
# epoch:10,batch_idx:400,running_loss:13.297862394750119
# epoch:10,batch_idx:400,running_loss:12.834350786209107
# epoch:10,batch_idx:400,running_loss:12.433557198941708
# epoch:10,batch_idx:400,running_loss:12.181541378200054
# epoch:10,batch_idx:400,running_loss:13.71732723981142
# epoch:10,batch_idx:400,running_loss:14.299432008862496
# epoch:10,batch_idx:400,running_loss:14.738833305090665
# epoch:10,batch_idx:400,running_loss:14.705325963497161
# epoch:10,batch_idx:400,running_loss:14.665745207369328
# epoch:10,batch_idx:400,running_loss:14.52168373838067
# epoch:10,batch_idx:400,running_loss:14.104031036794186
# epoch:10,batch_idx:400,running_loss:13.554997507929802
# epoch:10,batch_idx:400,running_loss:13.404380990862846
# epoch:10,batch_idx:400,running_loss:13.116245339512824
# epoch:10,batch_idx:400,running_loss:12.622977944016457
# epoch:10,batch_idx:400,running_loss:12.243697372674943
# epoch:10,batch_idx:400,running_loss:13.84469653069973
# epoch:10,batch_idx:400,running_loss:13.949310624301434
# epoch:10,batch_idx:400,running_loss:14.563328415453434
# epoch:10,batch_idx:400,running_loss:14.678820132613183
# epoch:10,batch_idx:400,running_loss:14.5212208583951
# epoch:10,batch_idx:400,running_loss:14.33014809936285
# epoch:10,batch_idx:400,running_loss:13.949428952336312
# epoch:10,batch_idx:400,running_loss:13.563579652905464
# epoch:10,batch_idx:400,running_loss:13.327215330302716
# epoch:10,batch_idx:400,running_loss:13.064322284758092
# epoch:10,batch_idx:400,running_loss:12.617896773219108
# epoch:10,batch_idx:400,running_loss:12.26773689776659
# ###epoch:10,train_loss:6.348959445953369

# %%
def load_net(path='multidata-epoch9.pt',net=None):
    net.load_state_dict(torch.load(path))
load_net(net=net)

# %%
def predict(prefix,num_preds,net,device):
    net.eval()
    state = net.begin_state(batch_size=1,device=device)
    outputs = [prefix[0]]
    get_input = lambda:torch.tensor([outputs[-1]],device=device).reshape(1,1)
    for y in prefix[1:]:
        _,state = net(get_input(),state)
        outputs.append(y)
    for _ in range(num_preds):
        y,state = net(get_input(),state)
        outputs.append(y.reshape(1).detach()[0])
    tmp = []
    for t in outputs:
        tmp.append(t.item())
    outputs =tmp
    return outputs#torch.cat(outputs,dim=1)

# %%
test_dataset = WindDataSet('../data/wind_dataset144-2014/wind_dataset144/142.csv',num_steps=50)
test_loader = DataLoader(test_dataset,batch_size=1,shuffle=False)
preds,truth=None,None
for batch_idx,(X, y) in enumerate(test_loader):
    if batch_idx == 0:
        X = (X.reshape(-1).to(torch.float32))
        preds = predict(X,50,net,device)
    if batch_idx == 1:
        truth = np.array(X)
        break
print((preds[50:]))
print((truth.reshape(50)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# e:\MyProject\MachineLearning\wind_LSTM2\wind_LSTM_MO.ipynb Cell 14 line 7
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> if batch_idx == 0:
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     X = (X.reshape(-1).to(torch.float32))
# ----> <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>     preds = predict(X,50,net,device)
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> if batch_idx == 1:
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a>     truth = np.array(X)
#
# e:\MyProject\MachineLearning\wind_LSTM2\wind_LSTM_MO.ipynb Cell 14 line 7
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> get_input = lambda:torch.tensor([outputs[-1]],device=device).reshape(1,1)
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> for y in prefix[1:]:
# ----> <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>     _,state = net(get_input(),state)
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a>     outputs.append(y)
#       <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> for _ in range(num_preds):
#
# File c:\Users\92469\miniconda3\envs\d2l\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# e:\MyProject\MachineLearning\wind_LSTM2\wind_LSTM_MO.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=11'>12</a> def forward(self,x,state):
# ---> <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=12'>13</a>     x = torch.transpose(x,dim0=0,dim1=1).reshape((x.shape[1],-1,INPUT_SIZE))
#      <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=13'>14</a>     out,state = self.rnn(x,state)
#      <a href='vscode-notebook-cell:/e%3A/MyProject/MachineLearning/wind_LSTM2/wind_LSTM_MO.ipynb#X16sZmlsZQ%3D%3D?line=14'>15</a>     out = self.fc(out)
#
# RuntimeError: shape '[1, -1, 10]' is invalid for input of size 1
