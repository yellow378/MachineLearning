# %%
import pandas as pd
import numpy as np
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch
import torch.nn as nn

# %%
class WindDataSet(Dataset):
    def __init__(self,path,num_steps=50):
        self.data = []
        file = pd.read_csv(path,skiprows=1)
        self.wind = np.array(file['wind speed at 10m (m/s)']).reshape(1,-1)[0]
        wind_len = len(self.wind)
        for i in range(wind_len-num_steps-1):
            self.data.append((self.wind[i:i+num_steps],self.wind[i+1:i+num_steps+1]))
        self.data = self.data[:int(len(self.data)/50)*50]
    def __len__(self):
        return len(self.data)
    def __getitem__(self,index):
        seq,pre = self.data[index]
        return seq,pre

# %%
def try_gpu(i=0):
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')
try_gpu()
# Out:
# device(type='cpu')

# %%
INPUT_SIZE=1
HIDDEN_SIZE=128
BATCH_SIZE=50
DROP_RATE=0.2

class lstm(nn.Module):
    def __init__(self):
        super(lstm,self).__init__()
        self.rnn = nn.LSTM(input_size=INPUT_SIZE,hidden_size=HIDDEN_SIZE)
        self.fc = nn.Linear(HIDDEN_SIZE,1)
    def forward(self,x,state):
        out,state = self.rnn(x.T.reshape((x.shape[1],-1,1)),state)
        out = self.fc(out)
        return out,state
    def begin_state(self,batch_size,device):
        return (torch.zeros((1,batch_size,HIDDEN_SIZE),device=device),torch.zeros((1,batch_size, HIDDEN_SIZE), device=device))

# %%
net = lstm()
lr = 0.001
device = try_gpu()
print(device)
net = net.to(device)
optimizer = torch.optim.Adam(net.parameters(),lr=lr)
loss = nn.MSELoss()
epochs = 1
num_steps=50
# Out:
# cpu

# %%
def grad_clipping(net,theta):
    if isinstance(net,nn.Module):
        params = [p for p in net.parameters() if p.requires_grad]
    else:
        params = net.params
    norm = torch.sqrt(sum(torch.sum((p.grad ** 2)) for p in params))
    if norm > theta:
        for param in params:
            param.grad[:] *= theta/norm

# %%
def train_epoch(epoch,net,train_loader,device,train_loss):
    net.train()
    state=net.begin_state(batch_size=BATCH_SIZE, device=device)
    runing_loss=0
    for batch_idx,(X,y) in enumerate(train_loader):
        for s in state:
            s.detach_()
        optimizer.zero_grad()
        X,y = X.to(torch.float32).to(device),y.to(torch.float32).T.to(device)
        y_hat,state = net(X,state)
        y_hat = y_hat.reshape(num_steps,BATCH_SIZE)
        l = loss(y_hat,y)
        l.backward()
        grad_clipping(net, 1)
        optimizer.step()
        runing_loss += l.item()
        if batch_idx%100 == 99:
            print(f'epoch:{epoch+1},batch_idx:{batch_idx+1},running_loss:{runing_loss/100}')
            runing_loss = 0
        train_loss.append(l.item())

# %%
dataset = WindDataSet('../data/wind_dataset144-2014/wind_dataset144/1.csv',num_steps)
print(dataset.__len__())
# Out:
# 105050

# %%
def train(epochs):
    train_loss = []
    for epoch in range(epochs):
        for i in range(120):
            dataset = WindDataSet(f'./datasets/{i}.csv',num_steps)
            train_loader = DataLoader(dataset,batch_size=BATCH_SIZE,shuffle=False,num_workers=0)
            train_epoch(epoch,net,train_loader,device,train_loss)
        print(f'###epoch:{epoch+1},train_loss:{train_loss[-1]}')

# %%
train(epochs)
# Out:
# epoch:1,batch_idx:100,running_loss:6.337180415913463
# epoch:1,batch_idx:200,running_loss:0.6713938944879919
# epoch:1,batch_idx:300,running_loss:0.42530034283641727
# epoch:1,batch_idx:400,running_loss:0.28629369055619464
# epoch:1,batch_idx:500,running_loss:0.20516959247179328
# epoch:1,batch_idx:600,running_loss:0.15068694863002746
# epoch:1,batch_idx:700,running_loss:0.152924257008126
# epoch:1,batch_idx:800,running_loss:0.1843894370063208
# epoch:1,batch_idx:900,running_loss:0.21094414785504342
# epoch:1,batch_idx:1000,running_loss:0.2295802732463926
# epoch:1,batch_idx:1100,running_loss:0.17408983214292675
# epoch:1,batch_idx:1200,running_loss:0.23392418023664505
# epoch:1,batch_idx:1300,running_loss:0.0941151354345493
# epoch:1,batch_idx:1400,running_loss:0.12239223188487813
# epoch:1,batch_idx:1500,running_loss:0.07022963202325627
# epoch:1,batch_idx:1600,running_loss:0.07245184284052812
# epoch:1,batch_idx:1700,running_loss:0.021008826259057967
# epoch:1,batch_idx:1800,running_loss:0.01834531005937606
# epoch:1,batch_idx:1900,running_loss:0.017804358331486584
# epoch:1,batch_idx:2000,running_loss:0.007022714000486303
# epoch:1,batch_idx:2100,running_loss:0.020888334553164897
# epoch:1,batch_idx:100,running_loss:0.020164544458384625
# epoch:1,batch_idx:200,running_loss:0.008059690033260267
# epoch:1,batch_idx:300,running_loss:0.03782811402401421
# epoch:1,batch_idx:400,running_loss:0.031016855005873367
# epoch:1,batch_idx:500,running_loss:0.07130040210206062
# epoch:1,batch_idx:600,running_loss:0.09559655929217115
# epoch:1,batch_idx:700,running_loss:0.1252098789426964
# epoch:1,batch_idx:800,running_loss:0.21360475352033972
# epoch:1,batch_idx:900,running_loss:0.19623422947712243
# epoch:1,batch_idx:1000,running_loss:0.2855407721735537
# epoch:1,batch_idx:1100,running_loss:0.1976491775503382
# epoch:1,batch_idx:1200,running_loss:0.22391666255425663
# epoch:1,batch_idx:1300,running_loss:0.09695041452534497
# epoch:1,batch_idx:1400,running_loss:0.12367606326006353
# epoch:1,batch_idx:1500,running_loss:0.08725345654645934
# epoch:1,batch_idx:1600,running_loss:0.0982127751968801
# epoch:1,batch_idx:1700,running_loss:0.030208355359500273
# epoch:1,batch_idx:1800,running_loss:0.0191132465103874
# epoch:1,batch_idx:1900,running_loss:0.0183961684233509
# epoch:1,batch_idx:2000,running_loss:0.005795455095649231
# epoch:1,batch_idx:2100,running_loss:0.020114102262305096
# epoch:1,batch_idx:100,running_loss:0.009060973842279054
# epoch:1,batch_idx:200,running_loss:0.005158998977276496
# epoch:1,batch_idx:300,running_loss:0.026265096023707885
# epoch:1,batch_idx:400,running_loss:0.025296743831131608
# epoch:1,batch_idx:500,running_loss:0.07343326073198114
# epoch:1,batch_idx:600,running_loss:0.07858316262252629
# epoch:1,batch_idx:700,running_loss:0.121505967566045
# epoch:1,batch_idx:800,running_loss:0.17521716948831453
# epoch:1,batch_idx:900,running_loss:0.17923762443009764
# epoch:1,batch_idx:1000,running_loss:0.2694802160654217
# epoch:1,batch_idx:1100,running_loss:0.1876189841562882
# epoch:1,batch_idx:1200,running_loss:0.22184681452345104
# epoch:1,batch_idx:1300,running_loss:0.08116519312839955
# epoch:1,batch_idx:1400,running_loss:0.12154571887571365
# epoch:1,batch_idx:1500,running_loss:0.08574519822373987
# epoch:1,batch_idx:1600,running_loss:0.0615956861525774
# epoch:1,batch_idx:1700,running_loss:0.02209513528679963
# epoch:1,batch_idx:1800,running_loss:0.01524224198597949
# epoch:1,batch_idx:1900,running_loss:0.01880787473928649
# epoch:1,batch_idx:2000,running_loss:0.004632985743664903
# epoch:1,batch_idx:2100,running_loss:0.01861688294680789
# epoch:1,batch_idx:100,running_loss:0.02149573681788752
# epoch:1,batch_idx:200,running_loss:0.004858969091146719
# epoch:1,batch_idx:300,running_loss:0.027291996353887953
# epoch:1,batch_idx:400,running_loss:0.031436812548781744
# epoch:1,batch_idx:500,running_loss:0.07260518701514229
# epoch:1,batch_idx:600,running_loss:0.0874168329371605
# epoch:1,batch_idx:700,running_loss:0.14427568217157385
# epoch:1,batch_idx:800,running_loss:0.19907317487639375
# epoch:1,batch_idx:900,running_loss:0.21519429484847932
# epoch:1,batch_idx:1000,running_loss:0.3258243556972593
# epoch:1,batch_idx:1100,running_loss:0.20562458117958157
# epoch:1,batch_idx:1200,running_loss:0.29512618590611966
# epoch:1,batch_idx:1300,running_loss:0.10212165950331836
# epoch:1,batch_idx:1400,running_loss:0.13786309890449047
# epoch:1,batch_idx:1500,running_loss:0.09922729740850628
# epoch:1,batch_idx:1600,running_loss:0.06929194936295971
# epoch:1,batch_idx:1700,running_loss:0.022959343978436665
# epoch:1,batch_idx:1800,running_loss:0.01637902013666462
# epoch:1,batch_idx:1900,running_loss:0.01663556742016226
# epoch:1,batch_idx:2000,running_loss:0.005257433060905896
# epoch:1,batch_idx:2100,running_loss:0.020612357271893415
# epoch:1,batch_idx:100,running_loss:0.015721381354960613
# epoch:1,batch_idx:200,running_loss:0.013527531383442693
# epoch:1,batch_idx:300,running_loss:0.026049799277679996
# epoch:1,batch_idx:400,running_loss:0.04626814603339881
# epoch:1,batch_idx:500,running_loss:0.07575456534454134
# epoch:1,batch_idx:600,running_loss:0.11933238082216122
# epoch:1,batch_idx:700,running_loss:0.1569362428341992
# epoch:1,batch_idx:800,running_loss:0.22047245787689462
# epoch:1,batch_idx:900,running_loss:0.24688509724102914
# epoch:1,batch_idx:1000,running_loss:0.38406767962500454
# epoch:1,batch_idx:1100,running_loss:0.23535366629250348
# epoch:1,batch_idx:1200,running_loss:0.2510865991935134
# epoch:1,batch_idx:1300,running_loss:0.12048684643115848
# epoch:1,batch_idx:1400,running_loss:0.1690943699935451
# epoch:1,batch_idx:1500,running_loss:0.12005123163340613
# epoch:1,batch_idx:1600,running_loss:0.07337352707050741
# epoch:1,batch_idx:1700,running_loss:0.028176144340541213
# epoch:1,batch_idx:1800,running_loss:0.018844716406892986
# epoch:1,batch_idx:1900,running_loss:0.019453632158692925
# epoch:1,batch_idx:2000,running_loss:0.005770638637477532
# epoch:1,batch_idx:2100,running_loss:0.021057821646681987
# epoch:1,batch_idx:100,running_loss:0.01201787995552877
# epoch:1,batch_idx:200,running_loss:0.010652953198878094
# epoch:1,batch_idx:300,running_loss:0.024323273938789497
# epoch:1,batch_idx:400,running_loss:0.053843714243266734
# epoch:1,batch_idx:500,running_loss:0.1055487865419127
# epoch:1,batch_idx:600,running_loss:0.12257317431038245
# epoch:1,batch_idx:700,running_loss:0.15258693464566023
# epoch:1,batch_idx:800,running_loss:0.2410653463122435
# epoch:1,batch_idx:900,running_loss:0.28583401449490337
# epoch:1,batch_idx:1000,running_loss:0.36456979024223984
# epoch:1,batch_idx:1100,running_loss:0.24896198228467256
# epoch:1,batch_idx:1200,running_loss:0.31045260788872836
# epoch:1,batch_idx:1300,running_loss:0.14109140218701213
# epoch:1,batch_idx:1400,running_loss:0.17902519278228282
# epoch:1,batch_idx:1500,running_loss:0.13544155981158837
# epoch:1,batch_idx:1600,running_loss:0.07519058978417888
# epoch:1,batch_idx:1700,running_loss:0.028327822550199926
# epoch:1,batch_idx:1800,running_loss:0.01953720053366851
# epoch:1,batch_idx:1900,running_loss:0.022940299745532685
# epoch:1,batch_idx:2000,running_loss:0.006645024693279993
# epoch:1,batch_idx:2100,running_loss:0.024277484795020426
# epoch:1,batch_idx:100,running_loss:0.026288012012955733
# epoch:1,batch_idx:200,running_loss:0.007881162008852699
# epoch:1,batch_idx:300,running_loss:0.029211080008535645
# epoch:1,batch_idx:400,running_loss:0.04546368447830901
# epoch:1,batch_idx:500,running_loss:0.10277972693089396
# epoch:1,batch_idx:600,running_loss:0.13326082598185165
# epoch:1,batch_idx:700,running_loss:0.17215223758015782
# epoch:1,batch_idx:800,running_loss:0.23684026163769886
# epoch:1,batch_idx:900,running_loss:0.31500208854675293
# epoch:1,batch_idx:1000,running_loss:0.39292717320844534
# epoch:1,batch_idx:1100,running_loss:0.2652076179813594
# epoch:1,batch_idx:1200,running_loss:0.2874511052388698
# epoch:1,batch_idx:1300,running_loss:0.13504842078778892
# epoch:1,batch_idx:1400,running_loss:0.17064361124299465
# epoch:1,batch_idx:1500,running_loss:0.16241074655205012
# epoch:1,batch_idx:1600,running_loss:0.08089342377148569
# epoch:1,batch_idx:1700,running_loss:0.0284258705121465
# epoch:1,batch_idx:1800,running_loss:0.021891173076583073
# epoch:1,batch_idx:1900,running_loss:0.019369725791621023
# epoch:1,batch_idx:2000,running_loss:0.007765481637907214
# epoch:1,batch_idx:2100,running_loss:0.020750666161475237
# epoch:1,batch_idx:100,running_loss:0.01621592034585774
# epoch:1,batch_idx:200,running_loss:0.006825877194060013
# epoch:1,batch_idx:300,running_loss:0.0333853155025281
# epoch:1,batch_idx:400,running_loss:0.04567061485024169
# epoch:1,batch_idx:500,running_loss:0.09523263206647244
# epoch:1,batch_idx:600,running_loss:0.1484782101691235
# epoch:1,batch_idx:700,running_loss:0.15992906050989406
# epoch:1,batch_idx:800,running_loss:0.27388017481891436
# epoch:1,batch_idx:900,running_loss:0.31249259440461175
# epoch:1,batch_idx:1000,running_loss:0.36686596205458044
# epoch:1,batch_idx:1100,running_loss:0.270520683452487
# epoch:1,batch_idx:1200,running_loss:0.2602695648325607
# epoch:1,batch_idx:1300,running_loss:0.13733287603128702
# epoch:1,batch_idx:1400,running_loss:0.17643625690136105
# epoch:1,batch_idx:1500,running_loss:0.1665044323168695
# epoch:1,batch_idx:1600,running_loss:0.07404017344117164
# epoch:1,batch_idx:1700,running_loss:0.029294583804439753
# epoch:1,batch_idx:1800,running_loss:0.024582814674358813
# epoch:1,batch_idx:1900,running_loss:0.018720843842311298
# epoch:1,batch_idx:2000,running_loss:0.006081873416551389
# epoch:1,batch_idx:2100,running_loss:0.018681833510345313
# epoch:1,batch_idx:100,running_loss:0.017604045558837243
# epoch:1,batch_idx:200,running_loss:0.006112825266318396
# epoch:1,batch_idx:300,running_loss:0.029828676484758034
# epoch:1,batch_idx:400,running_loss:0.04228822026401758
# epoch:1,batch_idx:500,running_loss:0.09541144206013996
# epoch:1,batch_idx:600,running_loss:0.14373466976336202
# epoch:1,batch_idx:700,running_loss:0.1646168497367762
# epoch:1,batch_idx:800,running_loss:0.25307517365552484
# epoch:1,batch_idx:900,running_loss:0.33923874333733695
# epoch:1,batch_idx:1000,running_loss:0.3814333600830287
# epoch:1,batch_idx:1100,running_loss:0.2881880901008844
# epoch:1,batch_idx:1200,running_loss:0.2907928090821952
# epoch:1,batch_idx:1300,running_loss:0.14374662240967154
# epoch:1,batch_idx:1400,running_loss:0.18012310289079322
# epoch:1,batch_idx:1500,running_loss:0.16332402294734494
# epoch:1,batch_idx:1600,running_loss:0.07451833414495923
# epoch:1,batch_idx:1700,running_loss:0.02948838655720465
# epoch:1,batch_idx:1800,running_loss:0.02689034733106382
# epoch:1,batch_idx:1900,running_loss:0.017880530018301213
# epoch:1,batch_idx:2000,running_loss:0.006169297900632955
# epoch:1,batch_idx:2100,running_loss:0.016121082542813383
# epoch:1,batch_idx:100,running_loss:0.02114457314979518
# epoch:1,batch_idx:200,running_loss:0.008701701562386007
# epoch:1,batch_idx:300,running_loss:0.03264229464868549
# epoch:1,batch_idx:400,running_loss:0.05742252625583205
# epoch:1,batch_idx:500,running_loss:0.09738322991004679
# epoch:1,batch_idx:600,running_loss:0.1425309609354008
# epoch:1,batch_idx:700,running_loss:0.1893636396038346
# epoch:1,batch_idx:800,running_loss:0.25277861444046723
# epoch:1,batch_idx:900,running_loss:0.3209695382206701
# epoch:1,batch_idx:1000,running_loss:0.36722492253873495
# epoch:1,batch_idx:1100,running_loss:0.2824277055170387
# epoch:1,batch_idx:1200,running_loss:0.27352999987080695
# epoch:1,batch_idx:1300,running_loss:0.13094292688183487
# epoch:1,batch_idx:1400,running_loss:0.17803894788958133
# epoch:1,batch_idx:1500,running_loss:0.14972080885898323
# epoch:1,batch_idx:1600,running_loss:0.06618476701900362
# epoch:1,batch_idx:1700,running_loss:0.03147091700229794
# epoch:1,batch_idx:1800,running_loss:0.027092506382032297
# epoch:1,batch_idx:1900,running_loss:0.01433484754525125
# epoch:1,batch_idx:2000,running_loss:0.006681613110704348
# epoch:1,batch_idx:2100,running_loss:0.01653331987094134
# epoch:1,batch_idx:100,running_loss:0.03199605928792153
# epoch:1,batch_idx:200,running_loss:0.012734763881890104
# epoch:1,batch_idx:300,running_loss:0.03294990169175435
# epoch:1,batch_idx:400,running_loss:0.047785211101872845
# epoch:1,batch_idx:500,running_loss:0.0863465268688742
# epoch:1,batch_idx:600,running_loss:0.13813715284690262
# epoch:1,batch_idx:700,running_loss:0.19317736043245531
# epoch:1,batch_idx:800,running_loss:0.2041782989888452
# epoch:1,batch_idx:900,running_loss:0.32480453832075
# epoch:1,batch_idx:1000,running_loss:0.37756343513727186
# epoch:1,batch_idx:1100,running_loss:0.29064393586479126
# epoch:1,batch_idx:1200,running_loss:0.27718918219674377
# epoch:1,batch_idx:1300,running_loss:0.12531506806146353
# epoch:1,batch_idx:1400,running_loss:0.17860104632331059
# epoch:1,batch_idx:1500,running_loss:0.14061400563456117
# epoch:1,batch_idx:1600,running_loss:0.06780480287037789
# epoch:1,batch_idx:1700,running_loss:0.030184885171474888
# epoch:1,batch_idx:1800,running_loss:0.033057126707863066
# epoch:1,batch_idx:1900,running_loss:0.014387814789370169
# epoch:1,batch_idx:2000,running_loss:0.005952372853644192
# epoch:1,batch_idx:2100,running_loss:0.018065017837507184
# epoch:1,batch_idx:100,running_loss:0.03165430436783936
# epoch:1,batch_idx:200,running_loss:0.007026548873982392
# epoch:1,batch_idx:300,running_loss:0.029527655778802
# epoch:1,batch_idx:400,running_loss:0.053911020155064764
# epoch:1,batch_idx:500,running_loss:0.08086263369361404
# epoch:1,batch_idx:600,running_loss:0.13470695073483513
# epoch:1,batch_idx:700,running_loss:0.20872179211117328
# epoch:1,batch_idx:800,running_loss:0.21963694996433333
# epoch:1,batch_idx:900,running_loss:0.30401513745542613
# epoch:1,batch_idx:1000,running_loss:0.3578171327058226
# epoch:1,batch_idx:1100,running_loss:0.27028890591114757
# epoch:1,batch_idx:1200,running_loss:0.2975950919650495
# epoch:1,batch_idx:1300,running_loss:0.10921912281308323
# epoch:1,batch_idx:1400,running_loss:0.19330531131476164
# epoch:1,batch_idx:1500,running_loss:0.1330391699867323
# epoch:1,batch_idx:1600,running_loss:0.06745496873278171
# epoch:1,batch_idx:1700,running_loss:0.030129006635397672
# epoch:1,batch_idx:1800,running_loss:0.03253752846969291
# epoch:1,batch_idx:1900,running_loss:0.017171241435862614
# epoch:1,batch_idx:2000,running_loss:0.0056175187445478515
# epoch:1,batch_idx:2100,running_loss:0.019322113423259
# epoch:1,batch_idx:100,running_loss:0.020210593412048183
# epoch:1,batch_idx:200,running_loss:0.008716232237347868
# epoch:1,batch_idx:300,running_loss:0.02265154395106947
# epoch:1,batch_idx:400,running_loss:0.037826977593940686
# epoch:1,batch_idx:500,running_loss:0.07628660280053737
# epoch:1,batch_idx:600,running_loss:0.09144628524198196
# epoch:1,batch_idx:700,running_loss:0.1468498402077239
# epoch:1,batch_idx:800,running_loss:0.1647468762891367
# epoch:1,batch_idx:900,running_loss:0.21139443563297391
# epoch:1,batch_idx:1000,running_loss:0.3074422031827271
# epoch:1,batch_idx:1100,running_loss:0.20579368368256837
# epoch:1,batch_idx:1200,running_loss:0.26036882334854455
# epoch:1,batch_idx:1300,running_loss:0.09971550627145916
# epoch:1,batch_idx:1400,running_loss:0.13548167587723584
# epoch:1,batch_idx:1500,running_loss:0.08473261619452387
# epoch:1,batch_idx:1600,running_loss:0.07368002836359665
# epoch:1,batch_idx:1700,running_loss:0.026855692657409235
# epoch:1,batch_idx:1800,running_loss:0.020970586618059315
# epoch:1,batch_idx:1900,running_loss:0.0168178337108111
# epoch:1,batch_idx:2000,running_loss:0.005302324973163195
# epoch:1,batch_idx:2100,running_loss:0.02158467023720732
# epoch:1,batch_idx:100,running_loss:0.01595798832946457
# epoch:1,batch_idx:200,running_loss:0.008949854538950603
# epoch:1,batch_idx:300,running_loss:0.025868373955599964
# epoch:1,batch_idx:400,running_loss:0.0378755600558361
# epoch:1,batch_idx:500,running_loss:0.08048344567272579
# epoch:1,batch_idx:600,running_loss:0.10941211921512149
# epoch:1,batch_idx:700,running_loss:0.1472571605478879
# epoch:1,batch_idx:800,running_loss:0.1893408110551536
# epoch:1,batch_idx:900,running_loss:0.23323691964615137
# epoch:1,batch_idx:1000,running_loss:0.3432966944901273
# epoch:1,batch_idx:1100,running_loss:0.21186958856880664
# epoch:1,batch_idx:1200,running_loss:0.24544054039753974
# epoch:1,batch_idx:1300,running_loss:0.10758674148004502
# epoch:1,batch_idx:1400,running_loss:0.1488639038056135
# epoch:1,batch_idx:1500,running_loss:0.09912554341834039
# epoch:1,batch_idx:1600,running_loss:0.0817592147924006
# epoch:1,batch_idx:1700,running_loss:0.02714658226352185
# epoch:1,batch_idx:1800,running_loss:0.020173732834518888
# epoch:1,batch_idx:1900,running_loss:0.01754514689266216
# epoch:1,batch_idx:2000,running_loss:0.005101624760136474
# epoch:1,batch_idx:2100,running_loss:0.017327288156375287
# epoch:1,batch_idx:100,running_loss:0.01350222552951891
# epoch:1,batch_idx:200,running_loss:0.008027461451420095
# epoch:1,batch_idx:300,running_loss:0.028299472829676233
# epoch:1,batch_idx:400,running_loss:0.040482588829472664
# epoch:1,batch_idx:500,running_loss:0.08500046651170123
# epoch:1,batch_idx:600,running_loss:0.10921820496208966
# epoch:1,batch_idx:700,running_loss:0.15134464559378102
# epoch:1,batch_idx:800,running_loss:0.23262939468491822
# epoch:1,batch_idx:900,running_loss:0.24461770998314022
# epoch:1,batch_idx:1000,running_loss:0.35042705965461207
# epoch:1,batch_idx:1100,running_loss:0.212868656180799
# epoch:1,batch_idx:1200,running_loss:0.2690268172696233
# epoch:1,batch_idx:1300,running_loss:0.11017556277569383
# epoch:1,batch_idx:1400,running_loss:0.1505448851501569
# epoch:1,batch_idx:1500,running_loss:0.1125966316414997
# epoch:1,batch_idx:1600,running_loss:0.09412586540682241
# epoch:1,batch_idx:1700,running_loss:0.028865944066783413
# epoch:1,batch_idx:1800,running_loss:0.01861774179036729
# epoch:1,batch_idx:1900,running_loss:0.017452572338224854
# epoch:1,batch_idx:2000,running_loss:0.005004376726865303
# epoch:1,batch_idx:2100,running_loss:0.012614476721792016
# epoch:1,batch_idx:100,running_loss:0.28593960092635823
# epoch:1,batch_idx:200,running_loss:0.0060272048864862884
# epoch:1,batch_idx:300,running_loss:0.0317730704366113
# epoch:1,batch_idx:400,running_loss:0.04087994441040792
# epoch:1,batch_idx:500,running_loss:0.0853355367470067
# epoch:1,batch_idx:600,running_loss:0.10985453425091692
# epoch:1,batch_idx:700,running_loss:0.1507133756938856
# epoch:1,batch_idx:800,running_loss:0.24522154148668052
# epoch:1,batch_idx:900,running_loss:0.24754143859259783
# epoch:1,batch_idx:1000,running_loss:0.3471996784862131
# epoch:1,batch_idx:1100,running_loss:0.23222806164529175
# epoch:1,batch_idx:1200,running_loss:0.29138352485839275
# epoch:1,batch_idx:1300,running_loss:0.108851009006612
# epoch:1,batch_idx:1400,running_loss:0.15870811505476012
# epoch:1,batch_idx:1500,running_loss:0.11946140423649922
# epoch:1,batch_idx:1600,running_loss:0.08123072647722437
# epoch:1,batch_idx:1700,running_loss:0.025576068175723776
# epoch:1,batch_idx:1800,running_loss:0.01700313376961276
# epoch:1,batch_idx:1900,running_loss:0.016663531337107997
# epoch:1,batch_idx:2000,running_loss:0.005020932003099006
# epoch:1,batch_idx:2100,running_loss:0.013613697983382736
# epoch:1,batch_idx:100,running_loss:0.012404922507121227
# epoch:1,batch_idx:200,running_loss:0.00462966816208791
# epoch:1,batch_idx:300,running_loss:0.028816600512946024
# epoch:1,batch_idx:400,running_loss:0.03617321186582558
# epoch:1,batch_idx:500,running_loss:0.0840158498485107
# epoch:1,batch_idx:600,running_loss:0.12065051997546107
# epoch:1,batch_idx:700,running_loss:0.14882493657176382
# epoch:1,batch_idx:800,running_loss:0.2500939132983331
# epoch:1,batch_idx:900,running_loss:0.24895463537890464
# epoch:1,batch_idx:1000,running_loss:0.38245061519555745
# epoch:1,batch_idx:1100,running_loss:0.23334794880822302
# epoch:1,batch_idx:1200,running_loss:0.2997734781866893
# epoch:1,batch_idx:1300,running_loss:0.12415830612648278
# epoch:1,batch_idx:1400,running_loss:0.15959252460394055
# epoch:1,batch_idx:1500,running_loss:0.13507641363888978
# epoch:1,batch_idx:1600,running_loss:0.08896151539986022
# epoch:1,batch_idx:1700,running_loss:0.026939627275569363
# epoch:1,batch_idx:1800,running_loss:0.017968719145283103
# epoch:1,batch_idx:1900,running_loss:0.018213565389160066
# epoch:1,batch_idx:2000,running_loss:0.006962348472443409
# epoch:1,batch_idx:2100,running_loss:0.019945281368272845
# epoch:1,batch_idx:100,running_loss:0.0182449414927396
# epoch:1,batch_idx:200,running_loss:0.0055212794253020545
# epoch:1,batch_idx:300,running_loss:0.025510944923735224
# epoch:1,batch_idx:400,running_loss:0.04699814003310166
# epoch:1,batch_idx:500,running_loss:0.08653943552169949
# epoch:1,batch_idx:600,running_loss:0.12954969333135524
# epoch:1,batch_idx:700,running_loss:0.15607277499628253
# epoch:1,batch_idx:800,running_loss:0.2551166101126
# epoch:1,batch_idx:900,running_loss:0.2840418991586193
# epoch:1,batch_idx:1000,running_loss:0.37884094651322814
# epoch:1,batch_idx:1100,running_loss:0.2559182906150818
# epoch:1,batch_idx:1200,running_loss:0.3061769446078688
# epoch:1,batch_idx:1300,running_loss:0.11878675415180623
# epoch:1,batch_idx:1400,running_loss:0.16959326102398337
# epoch:1,batch_idx:1500,running_loss:0.13933658730005846
# epoch:1,batch_idx:1600,running_loss:0.07420882386621087
# epoch:1,batch_idx:1700,running_loss:0.025339449748862534
# epoch:1,batch_idx:1800,running_loss:0.019452508246176878
# epoch:1,batch_idx:1900,running_loss:0.017802262900513597
# epoch:1,batch_idx:2000,running_loss:0.007088978113606572
# epoch:1,batch_idx:2100,running_loss:0.020571898283960763
# epoch:1,batch_idx:100,running_loss:0.015581573219387792
# epoch:1,batch_idx:200,running_loss:0.008642442705458962
# epoch:1,batch_idx:300,running_loss:0.027009746727126183
# epoch:1,batch_idx:400,running_loss:0.048910533649614084
# epoch:1,batch_idx:500,running_loss:0.0826009054062888
# epoch:1,batch_idx:600,running_loss:0.12872630097786897
# epoch:1,batch_idx:700,running_loss:0.15804801739403046
# epoch:1,batch_idx:800,running_loss:0.23553475557593628
# epoch:1,batch_idx:900,running_loss:0.29368657095357775
# epoch:1,batch_idx:1000,running_loss:0.3890791288390756
# epoch:1,batch_idx:1100,running_loss:0.2598885568650439
# epoch:1,batch_idx:1200,running_loss:0.30657354823313654
# epoch:1,batch_idx:1300,running_loss:0.12432926930021494
# epoch:1,batch_idx:1400,running_loss:0.1701701005361974
# epoch:1,batch_idx:1500,running_loss:0.14446966496994718
# epoch:1,batch_idx:1600,running_loss:0.06908855094807223
# epoch:1,batch_idx:1700,running_loss:0.025741402944549917
# epoch:1,batch_idx:1800,running_loss:0.02123835514765233
# epoch:1,batch_idx:1900,running_loss:0.018323768103145996
# epoch:1,batch_idx:2000,running_loss:0.006829784294241108
# epoch:1,batch_idx:2100,running_loss:0.017216593450866638
# epoch:1,batch_idx:100,running_loss:0.012019369784975425
# epoch:1,batch_idx:200,running_loss:0.004181925455923192
# epoch:1,batch_idx:300,running_loss:0.024501079498440957
# epoch:1,batch_idx:400,running_loss:0.043585855084238574
# epoch:1,batch_idx:500,running_loss:0.08835434606589843
# epoch:1,batch_idx:600,running_loss:0.1297213517781347
# epoch:1,batch_idx:700,running_loss:0.1624384799262043
# epoch:1,batch_idx:800,running_loss:0.26908495353301987
# epoch:1,batch_idx:900,running_loss:0.31293063517892733
# epoch:1,batch_idx:1000,running_loss:0.36218174614943566
# epoch:1,batch_idx:1100,running_loss:0.2788762739067897
# epoch:1,batch_idx:1200,running_loss:0.27236393492668864
# epoch:1,batch_idx:1300,running_loss:0.13682728636311367
# epoch:1,batch_idx:1400,running_loss:0.1778504902916029
# epoch:1,batch_idx:1500,running_loss:0.15096753735560925
# epoch:1,batch_idx:1600,running_loss:0.06916455415077508
# epoch:1,batch_idx:1700,running_loss:0.02911292140488513
# epoch:1,batch_idx:1800,running_loss:0.019638875933014787
# epoch:1,batch_idx:1900,running_loss:0.01881372425123118
# epoch:1,batch_idx:2000,running_loss:0.006195135171874426
# epoch:1,batch_idx:2100,running_loss:0.017068397073016967
# epoch:1,batch_idx:100,running_loss:0.014275370552204548
# epoch:1,batch_idx:200,running_loss:0.006081904360617046
# epoch:1,batch_idx:300,running_loss:0.02420388549362542
# epoch:1,batch_idx:400,running_loss:0.03979818944819272
# epoch:1,batch_idx:500,running_loss:0.07892215170082637
# epoch:1,batch_idx:600,running_loss:0.12997520445962438
# epoch:1,batch_idx:700,running_loss:0.15723076820548157
# epoch:1,batch_idx:800,running_loss:0.24720626791240646
# epoch:1,batch_idx:900,running_loss:0.33986441638786347
# epoch:1,batch_idx:1000,running_loss:0.3706090893736109
# epoch:1,batch_idx:1100,running_loss:0.2850035896617919
# epoch:1,batch_idx:1200,running_loss:0.28284296617843213
# epoch:1,batch_idx:1300,running_loss:0.14097961958497762
# epoch:1,batch_idx:1400,running_loss:0.1672668266762048
# epoch:1,batch_idx:1500,running_loss:0.146591382548213
# epoch:1,batch_idx:1600,running_loss:0.0687573736719787
# epoch:1,batch_idx:1700,running_loss:0.029907797869527714
# epoch:1,batch_idx:1800,running_loss:0.020117188263102433
# epoch:1,batch_idx:1900,running_loss:0.015599903988768347
# epoch:1,batch_idx:2000,running_loss:0.005935631800093688
# epoch:1,batch_idx:2100,running_loss:0.015385846887365915
# epoch:1,batch_idx:100,running_loss:0.014958655821974389
# epoch:1,batch_idx:200,running_loss:0.00758867906202795
# epoch:1,batch_idx:300,running_loss:0.022522039796458556
# epoch:1,batch_idx:400,running_loss:0.03896374572184868
# epoch:1,batch_idx:500,running_loss:0.08036365131731145
# epoch:1,batch_idx:600,running_loss:0.1246828381693922
# epoch:1,batch_idx:700,running_loss:0.16827878256794065
# epoch:1,batch_idx:800,running_loss:0.2634804282011464
# epoch:1,batch_idx:900,running_loss:0.3164428721996956
# epoch:1,batch_idx:1000,running_loss:0.3603906783554703
# epoch:1,batch_idx:1100,running_loss:0.2793079368816689
# epoch:1,batch_idx:1200,running_loss:0.31212476757355034
# epoch:1,batch_idx:1300,running_loss:0.1250839955266565
# epoch:1,batch_idx:1400,running_loss:0.16779393349774183
# epoch:1,batch_idx:1500,running_loss:0.16210018784273417
# epoch:1,batch_idx:1600,running_loss:0.06514011904830114
# epoch:1,batch_idx:1700,running_loss:0.031561071844771506
# epoch:1,batch_idx:1800,running_loss:0.023698065312346445
# epoch:1,batch_idx:1900,running_loss:0.013979175713902805
# epoch:1,batch_idx:2000,running_loss:0.007234316646354273
# epoch:1,batch_idx:2100,running_loss:0.015107239222852514
# epoch:1,batch_idx:100,running_loss:0.02120584018586669
# epoch:1,batch_idx:200,running_loss:0.007620901511982084
# epoch:1,batch_idx:300,running_loss:0.025376712026190944
# epoch:1,batch_idx:400,running_loss:0.04476659352891147
# epoch:1,batch_idx:500,running_loss:0.07987330567440949
# epoch:1,batch_idx:600,running_loss:0.11721280404599384
# epoch:1,batch_idx:700,running_loss:0.20106933462433518
# epoch:1,batch_idx:800,running_loss:0.23206710296450184
# epoch:1,batch_idx:900,running_loss:0.32356496199034157
# epoch:1,batch_idx:1000,running_loss:0.36127958104480057
# epoch:1,batch_idx:1100,running_loss:0.2723530201194808
# epoch:1,batch_idx:1200,running_loss:0.25981192835606637
# epoch:1,batch_idx:1300,running_loss:0.11828978491481394
# epoch:1,batch_idx:1400,running_loss:0.17025309067685157
# epoch:1,batch_idx:1500,running_loss:0.14226536690723152
# epoch:1,batch_idx:1600,running_loss:0.06713051249505952
# epoch:1,batch_idx:1700,running_loss:0.03073133444413543
# epoch:1,batch_idx:1800,running_loss:0.027432036148384215
# epoch:1,batch_idx:1900,running_loss:0.013374245491286274
# epoch:1,batch_idx:2000,running_loss:0.005223044091835618
# epoch:1,batch_idx:2100,running_loss:0.016610052773612553
# epoch:1,batch_idx:100,running_loss:0.037547524484107274
# epoch:1,batch_idx:200,running_loss:0.005883671377669089
# epoch:1,batch_idx:300,running_loss:0.028654353832826017
# epoch:1,batch_idx:400,running_loss:0.04001098685665056
# epoch:1,batch_idx:500,running_loss:0.07883210631378461
# epoch:1,batch_idx:600,running_loss:0.1063375448435545
# epoch:1,batch_idx:700,running_loss:0.19775179015821778
# epoch:1,batch_idx:800,running_loss:0.23650491824606434
# epoch:1,batch_idx:900,running_loss:0.3063766895560548
# epoch:1,batch_idx:1000,running_loss:0.3630904567753896
# epoch:1,batch_idx:1100,running_loss:0.26154219737276435
# epoch:1,batch_idx:1200,running_loss:0.27929776477627455
# epoch:1,batch_idx:1300,running_loss:0.11423065818846226
# epoch:1,batch_idx:1400,running_loss:0.1778273380571045
# epoch:1,batch_idx:1500,running_loss:0.14778275267919525
# epoch:1,batch_idx:1600,running_loss:0.05567678679944947
# epoch:1,batch_idx:1700,running_loss:0.03023908193456009
# epoch:1,batch_idx:1800,running_loss:0.0275132857268909
# epoch:1,batch_idx:1900,running_loss:0.017424615866621026
# epoch:1,batch_idx:2000,running_loss:0.0058823411364573985
# epoch:1,batch_idx:2100,running_loss:0.019366513632703572
# epoch:1,batch_idx:100,running_loss:0.01993011369020678
# epoch:1,batch_idx:200,running_loss:0.009094778512662742
# epoch:1,batch_idx:300,running_loss:0.024018747965747024
# epoch:1,batch_idx:400,running_loss:0.04883384828572161
# epoch:1,batch_idx:500,running_loss:0.07611114619998262
# epoch:1,batch_idx:600,running_loss:0.10160442766966299
# epoch:1,batch_idx:700,running_loss:0.1613706982869189
# epoch:1,batch_idx:800,running_loss:0.19372479535755702
# epoch:1,batch_idx:900,running_loss:0.2411916937958449
# epoch:1,batch_idx:1000,running_loss:0.3459754020813853
# epoch:1,batch_idx:1100,running_loss:0.22663569713942708
# epoch:1,batch_idx:1200,running_loss:0.26172433204948903
# epoch:1,batch_idx:1300,running_loss:0.10518207483924925
# epoch:1,batch_idx:1400,running_loss:0.15232889471575617
# epoch:1,batch_idx:1500,running_loss:0.08978363374015316
# epoch:1,batch_idx:1600,running_loss:0.07803286896785722
# epoch:1,batch_idx:1700,running_loss:0.030333796762861312
# epoch:1,batch_idx:1800,running_loss:0.02098881515383255
# epoch:1,batch_idx:1900,running_loss:0.01664644563512411
# epoch:1,batch_idx:2000,running_loss:0.005147789682378061
# epoch:1,batch_idx:2100,running_loss:0.025708332464564592
# epoch:1,batch_idx:100,running_loss:0.018347567029995845
# epoch:1,batch_idx:200,running_loss:0.009291432554891798
# epoch:1,batch_idx:300,running_loss:0.02142772207618691
# epoch:1,batch_idx:400,running_loss:0.04037225479376502
# epoch:1,batch_idx:500,running_loss:0.08420879138429882
# epoch:1,batch_idx:600,running_loss:0.107496185277123
# epoch:1,batch_idx:700,running_loss:0.15538260850356891
# epoch:1,batch_idx:800,running_loss:0.19307442310033365
# epoch:1,batch_idx:900,running_loss:0.24210653363727033
# epoch:1,batch_idx:1000,running_loss:0.3522819439414889
# epoch:1,batch_idx:1100,running_loss:0.22691716650500893
# epoch:1,batch_idx:1200,running_loss:0.2726393694290891
# epoch:1,batch_idx:1300,running_loss:0.10911022810731083
# epoch:1,batch_idx:1400,running_loss:0.15194320727139712
# epoch:1,batch_idx:1500,running_loss:0.09999258382245899
# epoch:1,batch_idx:1600,running_loss:0.08682927263900637
# epoch:1,batch_idx:1700,running_loss:0.03241100298240781
# epoch:1,batch_idx:1800,running_loss:0.0179907633154653
# epoch:1,batch_idx:1900,running_loss:0.015374694114434533
# epoch:1,batch_idx:2000,running_loss:0.005083096302114427
# epoch:1,batch_idx:2100,running_loss:0.022003126428753603
# epoch:1,batch_idx:100,running_loss:0.014385433482239023
# epoch:1,batch_idx:200,running_loss:0.007292269094614312
# epoch:1,batch_idx:300,running_loss:0.020310794175311456
# epoch:1,batch_idx:400,running_loss:0.041169027370633555
# epoch:1,batch_idx:500,running_loss:0.07973875299707288
# epoch:1,batch_idx:600,running_loss:0.10526659673079848
# epoch:1,batch_idx:700,running_loss:0.15361231891671195
# epoch:1,batch_idx:800,running_loss:0.2197589267930016
# epoch:1,batch_idx:900,running_loss:0.24324065000284464
# epoch:1,batch_idx:1000,running_loss:0.35988363112788646
# epoch:1,batch_idx:1100,running_loss:0.22369361571967603
# epoch:1,batch_idx:1200,running_loss:0.2329361968766898
# epoch:1,batch_idx:1300,running_loss:0.10914915733039379
# epoch:1,batch_idx:1400,running_loss:0.15318601217586547
# epoch:1,batch_idx:1500,running_loss:0.10829728803830221
# epoch:1,batch_idx:1600,running_loss:0.07647504109190777
# epoch:1,batch_idx:1700,running_loss:0.02998067440581508
# epoch:1,batch_idx:1800,running_loss:0.019105634981533514
# epoch:1,batch_idx:1900,running_loss:0.015474479213007725
# epoch:1,batch_idx:2000,running_loss:0.005319808171188925
# epoch:1,batch_idx:2100,running_loss:0.01570056390395621
# epoch:1,batch_idx:100,running_loss:0.010500751943618524
# epoch:1,batch_idx:200,running_loss:0.0060705818369751795
# epoch:1,batch_idx:300,running_loss:0.021880351733998396
# epoch:1,batch_idx:400,running_loss:0.045447199400514365
# epoch:1,batch_idx:500,running_loss:0.08557069656933891
# epoch:1,batch_idx:600,running_loss:0.10926601051702164
# epoch:1,batch_idx:700,running_loss:0.15576691754627972
# epoch:1,batch_idx:800,running_loss:0.23220334961311892
# epoch:1,batch_idx:900,running_loss:0.25148745463695377
# epoch:1,batch_idx:1000,running_loss:0.38030785278882834
# epoch:1,batch_idx:1100,running_loss:0.21988360422663392
# epoch:1,batch_idx:1200,running_loss:0.29890472335740925
# epoch:1,batch_idx:1300,running_loss:0.11532425255514682
# epoch:1,batch_idx:1400,running_loss:0.1571558629022911
# epoch:1,batch_idx:1500,running_loss:0.10915598355699331
# epoch:1,batch_idx:1600,running_loss:0.09092709190445021
# epoch:1,batch_idx:1700,running_loss:0.027210632645292207
# epoch:1,batch_idx:1800,running_loss:0.016889175325632097
# epoch:1,batch_idx:1900,running_loss:0.013512238818220794
# epoch:1,batch_idx:2000,running_loss:0.005916597797768191
# epoch:1,batch_idx:2100,running_loss:0.013121694343572016
# epoch:1,batch_idx:100,running_loss:0.010046760395925957
# epoch:1,batch_idx:200,running_loss:0.005029012309096288
# epoch:1,batch_idx:300,running_loss:0.026900351657823195
# epoch:1,batch_idx:400,running_loss:0.03736994927516207
# epoch:1,batch_idx:500,running_loss:0.08554065026517492
# epoch:1,batch_idx:600,running_loss:0.12569717124104499
# epoch:1,batch_idx:700,running_loss:0.16038765550823883
# epoch:1,batch_idx:800,running_loss:0.22607020806171932
# epoch:1,batch_idx:900,running_loss:0.2672324027353898
# epoch:1,batch_idx:1000,running_loss:0.3709813020285219
# epoch:1,batch_idx:1100,running_loss:0.22672150772530586
# epoch:1,batch_idx:1200,running_loss:0.27252412363421175
# epoch:1,batch_idx:1300,running_loss:0.11131047145929188
# epoch:1,batch_idx:1400,running_loss:0.1560222621867433
# epoch:1,batch_idx:1500,running_loss:0.11511410258477554
# epoch:1,batch_idx:1600,running_loss:0.08383958557853476
# epoch:1,batch_idx:1700,running_loss:0.02711292711435817
# epoch:1,batch_idx:1800,running_loss:0.016075617144233546
# epoch:1,batch_idx:1900,running_loss:0.01537660829955712
# epoch:1,batch_idx:2000,running_loss:0.005629972059687134
# epoch:1,batch_idx:2100,running_loss:0.014289108483935706
# epoch:1,batch_idx:100,running_loss:0.016476894964580425
# epoch:1,batch_idx:200,running_loss:0.005519075830525253
# epoch:1,batch_idx:300,running_loss:0.027428871653974056
# epoch:1,batch_idx:400,running_loss:0.037781558621791195
# epoch:1,batch_idx:500,running_loss:0.0783077342400793
# epoch:1,batch_idx:600,running_loss:0.12021606324939058
# epoch:1,batch_idx:700,running_loss:0.15479999571340158
# epoch:1,batch_idx:800,running_loss:0.2622402492677793
# epoch:1,batch_idx:900,running_loss:0.25600854036863896
# epoch:1,batch_idx:1000,running_loss:0.3681130007840693
# epoch:1,batch_idx:1100,running_loss:0.24624131495133042
# epoch:1,batch_idx:1200,running_loss:0.2931172423157841
# epoch:1,batch_idx:1300,running_loss:0.10541561802849174
# epoch:1,batch_idx:1400,running_loss:0.15974786282051354
# epoch:1,batch_idx:1500,running_loss:0.13495696630561724
# epoch:1,batch_idx:1600,running_loss:0.07789218761958182
# epoch:1,batch_idx:1700,running_loss:0.024226503921672703
# epoch:1,batch_idx:1800,running_loss:0.017330421602237037
# epoch:1,batch_idx:1900,running_loss:0.015729718047368807
# epoch:1,batch_idx:2000,running_loss:0.006458732752653304
# epoch:1,batch_idx:2100,running_loss:0.01600420826813206
# epoch:1,batch_idx:100,running_loss:0.030074920516926795
# epoch:1,batch_idx:200,running_loss:0.005071278902469203
# epoch:1,batch_idx:300,running_loss:0.022825871616369113
# epoch:1,batch_idx:400,running_loss:0.042869546788278964
# epoch:1,batch_idx:500,running_loss:0.08722511451574974
# epoch:1,batch_idx:600,running_loss:0.12725001411279663
# epoch:1,batch_idx:700,running_loss:0.1464666967606172
# epoch:1,batch_idx:800,running_loss:0.2497060318174772
# epoch:1,batch_idx:900,running_loss:0.25640936245210466
# epoch:1,batch_idx:1000,running_loss:0.379229811350815
# epoch:1,batch_idx:1100,running_loss:0.25488837918732316
# epoch:1,batch_idx:1200,running_loss:0.3200005128514022
# epoch:1,batch_idx:1300,running_loss:0.11270060290582479
# epoch:1,batch_idx:1400,running_loss:0.16702216878533363
# epoch:1,batch_idx:1500,running_loss:0.14712827258743347
# epoch:1,batch_idx:1600,running_loss:0.06978964532259851
# epoch:1,batch_idx:1700,running_loss:0.025380560132325626
# epoch:1,batch_idx:1800,running_loss:0.017201389082474636
# epoch:1,batch_idx:1900,running_loss:0.01700169928255491
# epoch:1,batch_idx:2000,running_loss:0.005825473938020877
# epoch:1,batch_idx:2100,running_loss:0.015805101266887504
# epoch:1,batch_idx:100,running_loss:0.022656765083083882
# epoch:1,batch_idx:200,running_loss:0.005020693268452305
# epoch:1,batch_idx:300,running_loss:0.023694080086424946
# epoch:1,batch_idx:400,running_loss:0.03847402964602224
# epoch:1,batch_idx:500,running_loss:0.08312197137915063
# epoch:1,batch_idx:600,running_loss:0.12326530003570951
# epoch:1,batch_idx:700,running_loss:0.15197633344563655
# epoch:1,batch_idx:800,running_loss:0.2824093753518537
# epoch:1,batch_idx:900,running_loss:0.29715540417004377
# epoch:1,batch_idx:1000,running_loss:0.3882335015619174
# epoch:1,batch_idx:1100,running_loss:0.2594532996509224
# epoch:1,batch_idx:1200,running_loss:0.27100409707520157
# epoch:1,batch_idx:1300,running_loss:0.11643450329545885
# epoch:1,batch_idx:1400,running_loss:0.16156286104582251
# epoch:1,batch_idx:1500,running_loss:0.12461286028381437
# epoch:1,batch_idx:1600,running_loss:0.06949161862023175
# epoch:1,batch_idx:1700,running_loss:0.02527343086199835
# epoch:1,batch_idx:1800,running_loss:0.017698924121214078
# epoch:1,batch_idx:1900,running_loss:0.015074943088111468
# epoch:1,batch_idx:2000,running_loss:0.005688694453565404
# epoch:1,batch_idx:2100,running_loss:0.016096070338389838
# epoch:1,batch_idx:100,running_loss:0.03266451588540804
# epoch:1,batch_idx:200,running_loss:0.010374775893869809
# epoch:1,batch_idx:300,running_loss:0.03114872985170223
# epoch:1,batch_idx:400,running_loss:0.03488411409198307
# epoch:1,batch_idx:500,running_loss:0.0760641826922074
# epoch:1,batch_idx:600,running_loss:0.12204424590221606
# epoch:1,batch_idx:700,running_loss:0.1670180840289686
# epoch:1,batch_idx:800,running_loss:0.26603696029866114
# epoch:1,batch_idx:900,running_loss:0.2990074873762205
# epoch:1,batch_idx:1000,running_loss:0.379786910796538
# epoch:1,batch_idx:1100,running_loss:0.27524102832656355
# epoch:1,batch_idx:1200,running_loss:0.23314061135984956
# epoch:1,batch_idx:1300,running_loss:0.11816311247181148
# epoch:1,batch_idx:1400,running_loss:0.1746039126999676
# epoch:1,batch_idx:1500,running_loss:0.14365858243545518
# epoch:1,batch_idx:1600,running_loss:0.06004793420666829
# epoch:1,batch_idx:1700,running_loss:0.028262979172868654
# epoch:1,batch_idx:1800,running_loss:0.018967686711694114
# epoch:1,batch_idx:1900,running_loss:0.014268445018969941
# epoch:1,batch_idx:2000,running_loss:0.005129877879517153
# epoch:1,batch_idx:2100,running_loss:0.01852925841405522
# epoch:1,batch_idx:100,running_loss:0.03256998510332778
# epoch:1,batch_idx:200,running_loss:0.007928581692976878
# epoch:1,batch_idx:300,running_loss:0.0328098513558507
# epoch:1,batch_idx:400,running_loss:0.037544794469722545
# epoch:1,batch_idx:500,running_loss:0.07783399140869733
# epoch:1,batch_idx:600,running_loss:0.11342761200619861
# epoch:1,batch_idx:700,running_loss:0.1783011710620485
# epoch:1,batch_idx:800,running_loss:0.27013904268387706
# epoch:1,batch_idx:900,running_loss:0.311858681300655
# epoch:1,batch_idx:1000,running_loss:0.37861661247443407
# epoch:1,batch_idx:1100,running_loss:0.26798569758888335
# epoch:1,batch_idx:1200,running_loss:0.3124488786701113
# epoch:1,batch_idx:1300,running_loss:0.12340052002109587
# epoch:1,batch_idx:1400,running_loss:0.17501757504884152
# epoch:1,batch_idx:1500,running_loss:0.14682790915947408
# epoch:1,batch_idx:1600,running_loss:0.06777711041155271
# epoch:1,batch_idx:1700,running_loss:0.028313850602135062
# epoch:1,batch_idx:1800,running_loss:0.02136237012629863
# epoch:1,batch_idx:1900,running_loss:0.015404746019921731
# epoch:1,batch_idx:2000,running_loss:0.005837680237018503
# epoch:1,batch_idx:2100,running_loss:0.018876089573896023
# epoch:1,batch_idx:100,running_loss:0.038374668947653845
# epoch:1,batch_idx:200,running_loss:0.006402128226181958
# epoch:1,batch_idx:300,running_loss:0.03376770610571839
# epoch:1,batch_idx:400,running_loss:0.03296258653572295
# epoch:1,batch_idx:500,running_loss:0.080663294774713
# epoch:1,batch_idx:600,running_loss:0.11308044914156198
# epoch:1,batch_idx:700,running_loss:0.21118515230831691
# epoch:1,batch_idx:800,running_loss:0.24432401024503633
# epoch:1,batch_idx:900,running_loss:0.3130456417426467
# epoch:1,batch_idx:1000,running_loss:0.3815330256847665
# epoch:1,batch_idx:1100,running_loss:0.2752446005027741
# epoch:1,batch_idx:1200,running_loss:0.26313248550519347
# epoch:1,batch_idx:1300,running_loss:0.10961107823532075
# epoch:1,batch_idx:1400,running_loss:0.16681644894648343
# epoch:1,batch_idx:1500,running_loss:0.15025429912144317
# epoch:1,batch_idx:1600,running_loss:0.06389581504277884
# epoch:1,batch_idx:1700,running_loss:0.026906618259381503
# epoch:1,batch_idx:1800,running_loss:0.021479076223331502
# epoch:1,batch_idx:1900,running_loss:0.018689448170771356
# epoch:1,batch_idx:2000,running_loss:0.005294791352353059
# epoch:1,batch_idx:2100,running_loss:0.01999178591009695
# epoch:1,batch_idx:100,running_loss:0.03719869455700973
# epoch:1,batch_idx:200,running_loss:0.007665521429153159
# epoch:1,batch_idx:300,running_loss:0.03058843705308391
# epoch:1,batch_idx:400,running_loss:0.03274307177984156
# epoch:1,batch_idx:500,running_loss:0.07867572851944715
# epoch:1,batch_idx:600,running_loss:0.10007996439002455
# epoch:1,batch_idx:700,running_loss:0.1982252307375893
# epoch:1,batch_idx:800,running_loss:0.2699285577679984
# epoch:1,batch_idx:900,running_loss:0.3538004548801109
# epoch:1,batch_idx:1000,running_loss:0.3556804059958085
# epoch:1,batch_idx:1100,running_loss:0.2561551377410069
# epoch:1,batch_idx:1200,running_loss:0.23154384809546172
# epoch:1,batch_idx:1300,running_loss:0.1149469729186967
# epoch:1,batch_idx:1400,running_loss:0.17223553743213416
# epoch:1,batch_idx:1500,running_loss:0.1421541496133432
# epoch:1,batch_idx:1600,running_loss:0.06177034515305422
# epoch:1,batch_idx:1700,running_loss:0.027604375415248798
# epoch:1,batch_idx:1800,running_loss:0.024037598713184706
# epoch:1,batch_idx:1900,running_loss:0.016643221577396616
# epoch:1,batch_idx:2000,running_loss:0.00530712497071363
# epoch:1,batch_idx:2100,running_loss:0.023025268362835048
# epoch:1,batch_idx:100,running_loss:0.06709394804260228
# epoch:1,batch_idx:200,running_loss:0.013130555635434575
# epoch:1,batch_idx:300,running_loss:0.022979291629162617
# epoch:1,batch_idx:400,running_loss:0.048377549779834224
# epoch:1,batch_idx:500,running_loss:0.09228648357791826
# epoch:1,batch_idx:600,running_loss:0.10575158071704209
# epoch:1,batch_idx:700,running_loss:0.1702790250326507
# epoch:1,batch_idx:800,running_loss:0.19069599242997357
# epoch:1,batch_idx:900,running_loss:0.257410670502577
# epoch:1,batch_idx:1000,running_loss:0.3779679415328428
# epoch:1,batch_idx:1100,running_loss:0.2191574450954795
# epoch:1,batch_idx:1200,running_loss:0.2465509527316317
# epoch:1,batch_idx:1300,running_loss:0.09992110974853859
# epoch:1,batch_idx:1400,running_loss:0.18688119939994066
# epoch:1,batch_idx:1500,running_loss:0.08851833443157375
# epoch:1,batch_idx:1600,running_loss:0.07713724126340821
# epoch:1,batch_idx:1700,running_loss:0.033943071141839025
# epoch:1,batch_idx:1800,running_loss:0.017650480704614894
# epoch:1,batch_idx:1900,running_loss:0.015881748204119504
# epoch:1,batch_idx:2000,running_loss:0.00537600427865982
# epoch:1,batch_idx:2100,running_loss:0.02822152069362346
# epoch:1,batch_idx:100,running_loss:0.04854435093002394
# epoch:1,batch_idx:200,running_loss:0.013143566939397715
# epoch:1,batch_idx:300,running_loss:0.022743598174420187
# epoch:1,batch_idx:400,running_loss:0.04298427308502142
# epoch:1,batch_idx:500,running_loss:0.08364938987302593
# epoch:1,batch_idx:600,running_loss:0.11084175647469237
# epoch:1,batch_idx:700,running_loss:0.1729602821636945
# epoch:1,batch_idx:800,running_loss:0.19847328372532502
# epoch:1,batch_idx:900,running_loss:0.24273456861730666
# epoch:1,batch_idx:1000,running_loss:0.3867403220105916
# epoch:1,batch_idx:1100,running_loss:0.2438482582755387
# epoch:1,batch_idx:1200,running_loss:0.2724673886410892
# epoch:1,batch_idx:1300,running_loss:0.10237216621637345
# epoch:1,batch_idx:1400,running_loss:0.16290556894615293
# epoch:1,batch_idx:1500,running_loss:0.09195325533626601
# epoch:1,batch_idx:1600,running_loss:0.07832118108635769
# epoch:1,batch_idx:1700,running_loss:0.03314904927741736
# epoch:1,batch_idx:1800,running_loss:0.017736106054799167
# epoch:1,batch_idx:1900,running_loss:0.015465681498753839
# epoch:1,batch_idx:2000,running_loss:0.005264975052559748
# epoch:1,batch_idx:2100,running_loss:0.026807358993391973
# epoch:1,batch_idx:100,running_loss:0.028450079592876137
# epoch:1,batch_idx:200,running_loss:0.010954225121531635
# epoch:1,batch_idx:300,running_loss:0.023106208278040868
# epoch:1,batch_idx:400,running_loss:0.04115773240977433
# epoch:1,batch_idx:500,running_loss:0.08669471310044173
# epoch:1,batch_idx:600,running_loss:0.11686966036213561
# epoch:1,batch_idx:700,running_loss:0.1576804960356094
# epoch:1,batch_idx:800,running_loss:0.20626308857346884
# epoch:1,batch_idx:900,running_loss:0.2430235527595505
# epoch:1,batch_idx:1000,running_loss:0.35948926058597863
# epoch:1,batch_idx:1100,running_loss:0.23270227912813424
# epoch:1,batch_idx:1200,running_loss:0.22894714070018382
# epoch:1,batch_idx:1300,running_loss:0.1080065226694569
# epoch:1,batch_idx:1400,running_loss:0.16942922639194877
# epoch:1,batch_idx:1500,running_loss:0.10245743054663763
# epoch:1,batch_idx:1600,running_loss:0.09552938072709366
# epoch:1,batch_idx:1700,running_loss:0.03134652992826886
# epoch:1,batch_idx:1800,running_loss:0.018276833540876395
# epoch:1,batch_idx:1900,running_loss:0.015581213982077315
# epoch:1,batch_idx:2000,running_loss:0.0051273710795794614
# epoch:1,batch_idx:2100,running_loss:0.025106410771259108
# epoch:1,batch_idx:100,running_loss:0.021789361865085084
# epoch:1,batch_idx:200,running_loss:0.006643318058049772
# epoch:1,batch_idx:300,running_loss:0.019590469117683824
# epoch:1,batch_idx:400,running_loss:0.04491093935270328
# epoch:1,batch_idx:500,running_loss:0.08685043040430174
# epoch:1,batch_idx:600,running_loss:0.11423162128892728
# epoch:1,batch_idx:700,running_loss:0.16034930738504044
# epoch:1,batch_idx:800,running_loss:0.22549911324167624
# epoch:1,batch_idx:900,running_loss:0.2564682881347835
# epoch:1,batch_idx:1000,running_loss:0.3960036981385201
# epoch:1,batch_idx:1100,running_loss:0.2480691989744082
# epoch:1,batch_idx:1200,running_loss:0.29675544957164673
# epoch:1,batch_idx:1300,running_loss:0.11450973916333168
# epoch:1,batch_idx:1400,running_loss:0.16405782278627157
# epoch:1,batch_idx:1500,running_loss:0.10486350556835532
# epoch:1,batch_idx:1600,running_loss:0.08767973391339183
# epoch:1,batch_idx:1700,running_loss:0.028292443624231965
# epoch:1,batch_idx:1800,running_loss:0.017244694620603695
# epoch:1,batch_idx:1900,running_loss:0.014527326597599312
# epoch:1,batch_idx:2000,running_loss:0.005135173079324886
# epoch:1,batch_idx:2100,running_loss:0.017416907049773726
# epoch:1,batch_idx:100,running_loss:0.01321385398390703
# epoch:1,batch_idx:200,running_loss:0.008480887407204136
# epoch:1,batch_idx:300,running_loss:0.01744872890325496
# epoch:1,batch_idx:400,running_loss:0.04242459626984783
# epoch:1,batch_idx:500,running_loss:0.08372661013680044
# epoch:1,batch_idx:600,running_loss:0.11568698332644999
# epoch:1,batch_idx:700,running_loss:0.15580512725515291
# epoch:1,batch_idx:800,running_loss:0.2235874337947462
# epoch:1,batch_idx:900,running_loss:0.27247574129607527
# epoch:1,batch_idx:1000,running_loss:0.3807125587435439
# epoch:1,batch_idx:1100,running_loss:0.25282140489201993
# epoch:1,batch_idx:1200,running_loss:0.29042407190892844
# epoch:1,batch_idx:1300,running_loss:0.11298221649136395
# epoch:1,batch_idx:1400,running_loss:0.15841950926464052
# epoch:1,batch_idx:1500,running_loss:0.11802390149561688
# epoch:1,batch_idx:1600,running_loss:0.08490446863812394
# epoch:1,batch_idx:1700,running_loss:0.027502579869469627
# epoch:1,batch_idx:1800,running_loss:0.016633530614199116
# epoch:1,batch_idx:1900,running_loss:0.01522766125795897
# epoch:1,batch_idx:2000,running_loss:0.005934850984776858
# epoch:1,batch_idx:2100,running_loss:0.01426656903960975
# epoch:1,batch_idx:100,running_loss:0.014638090730586554
# ...
# epoch:1,batch_idx:900,running_loss:0.26324127652682366
# epoch:1,batch_idx:1000,running_loss:0.37756999088684096
# epoch:1,batch_idx:1100,running_loss:0.22415436428040267
# epoch:1,batch_idx:1200,running_loss:0.24045886598993094
# epoch:1,batch_idx:1300,running_loss:0.12834528501145542
# epoch:1,batch_idx:1400,running_loss:0.15254991895752026
# epoch:1,batch_idx:1500,running_loss:0.1101178613002412
# epoch:1,batch_idx:1600,running_loss:0.1024133907572832
# epoch:1,batch_idx:1700,running_loss:0.02722921666572802
# epoch:1,batch_idx:1800,running_loss:0.026325169374467806
# epoch:1,batch_idx:1900,running_loss:0.020093556705105584
# epoch:1,batch_idx:2000,running_loss:0.00801330755261006
# epoch:1,batch_idx:2100,running_loss:0.01410433402255876
# epoch:1,batch_idx:100,running_loss:0.012714320372615474
# epoch:1,batch_idx:200,running_loss:0.006984103149734438
# epoch:1,batch_idx:300,running_loss:0.025862292001547757
# epoch:1,batch_idx:400,running_loss:0.02382998026208952
# epoch:1,batch_idx:500,running_loss:0.08331375054549425
# epoch:1,batch_idx:600,running_loss:0.1423647419072222
# epoch:1,batch_idx:700,running_loss:0.1875675813574344
# epoch:1,batch_idx:800,running_loss:0.29499076285632325
# epoch:1,batch_idx:900,running_loss:0.2811567561747506
# epoch:1,batch_idx:1000,running_loss:0.3902794468868524
# epoch:1,batch_idx:1100,running_loss:0.23978038875386118
# epoch:1,batch_idx:1200,running_loss:0.2616749108769
# epoch:1,batch_idx:1300,running_loss:0.1275318648526445
# epoch:1,batch_idx:1400,running_loss:0.15558575515635312
# epoch:1,batch_idx:1500,running_loss:0.11153116355417296
# epoch:1,batch_idx:1600,running_loss:0.0910645501432009
# epoch:1,batch_idx:1700,running_loss:0.02628138315049
# epoch:1,batch_idx:1800,running_loss:0.025591494902037083
# epoch:1,batch_idx:1900,running_loss:0.02097924632311333
# epoch:1,batch_idx:2000,running_loss:0.007621798237087205
# epoch:1,batch_idx:2100,running_loss:0.01431400862580631
# epoch:1,batch_idx:100,running_loss:0.012533468735346104
# epoch:1,batch_idx:200,running_loss:0.00694441030616872
# epoch:1,batch_idx:300,running_loss:0.017791574457660317
# epoch:1,batch_idx:400,running_loss:0.029146622105035932
# epoch:1,batch_idx:500,running_loss:0.0813016575522488
# epoch:1,batch_idx:600,running_loss:0.1458303435833659
# epoch:1,batch_idx:700,running_loss:0.15916061067022383
# epoch:1,batch_idx:800,running_loss:0.22480902037583292
# epoch:1,batch_idx:900,running_loss:0.2735372014530003
# epoch:1,batch_idx:1000,running_loss:0.39896171272266656
# epoch:1,batch_idx:1100,running_loss:0.19680770199280231
# epoch:1,batch_idx:1200,running_loss:0.22962263516150416
# epoch:1,batch_idx:1300,running_loss:0.09757283965591342
# epoch:1,batch_idx:1400,running_loss:0.1482290937937796
# epoch:1,batch_idx:1500,running_loss:0.09369429335463791
# epoch:1,batch_idx:1600,running_loss:0.07302544118254445
# epoch:1,batch_idx:1700,running_loss:0.028689415777334942
# epoch:1,batch_idx:1800,running_loss:0.01880462184344651
# epoch:1,batch_idx:1900,running_loss:0.012223238230217249
# epoch:1,batch_idx:2000,running_loss:0.005454708823526744
# epoch:1,batch_idx:2100,running_loss:0.027778842491970865
# epoch:1,batch_idx:100,running_loss:0.01679229541303357
# epoch:1,batch_idx:200,running_loss:0.006237823934352491
# epoch:1,batch_idx:300,running_loss:0.017518141010368707
# epoch:1,batch_idx:400,running_loss:0.028559841555543242
# epoch:1,batch_idx:500,running_loss:0.08981615885451902
# epoch:1,batch_idx:600,running_loss:0.1539127597922925
# epoch:1,batch_idx:700,running_loss:0.14555909425369465
# epoch:1,batch_idx:800,running_loss:0.2194227839144878
# epoch:1,batch_idx:900,running_loss:0.2521730433870107
# epoch:1,batch_idx:1000,running_loss:0.37932597276521846
# epoch:1,batch_idx:1100,running_loss:0.2057910727476701
# epoch:1,batch_idx:1200,running_loss:0.24023916782345622
# epoch:1,batch_idx:1300,running_loss:0.09602897252887488
# epoch:1,batch_idx:1400,running_loss:0.14201797201763838
# epoch:1,batch_idx:1500,running_loss:0.10068555669859051
# epoch:1,batch_idx:1600,running_loss:0.0714621436339803
# epoch:1,batch_idx:1700,running_loss:0.026998573824530466
# epoch:1,batch_idx:1800,running_loss:0.023049831883981825
# epoch:1,batch_idx:1900,running_loss:0.01181898221722804
# epoch:1,batch_idx:2000,running_loss:0.004792711215559393
# epoch:1,batch_idx:2100,running_loss:0.026921488888619935
# epoch:1,batch_idx:100,running_loss:0.019944766669068484
# epoch:1,batch_idx:200,running_loss:0.005477365793194622
# epoch:1,batch_idx:300,running_loss:0.01696279663941823
# epoch:1,batch_idx:400,running_loss:0.026035856676171535
# epoch:1,batch_idx:500,running_loss:0.08518918993824627
# epoch:1,batch_idx:600,running_loss:0.1564643474773038
# epoch:1,batch_idx:700,running_loss:0.15996755986940114
# epoch:1,batch_idx:800,running_loss:0.22036186722107232
# epoch:1,batch_idx:900,running_loss:0.25806221262551843
# epoch:1,batch_idx:1000,running_loss:0.4085663973982446
# epoch:1,batch_idx:1100,running_loss:0.1962220734776929
# epoch:1,batch_idx:1200,running_loss:0.23698874144814908
# epoch:1,batch_idx:1300,running_loss:0.10004181588068604
# epoch:1,batch_idx:1400,running_loss:0.15929562455508858
# epoch:1,batch_idx:1500,running_loss:0.10568238050444051
# epoch:1,batch_idx:1600,running_loss:0.08228648439631797
# epoch:1,batch_idx:1700,running_loss:0.029209633496357128
# epoch:1,batch_idx:1800,running_loss:0.022800590199185535
# epoch:1,batch_idx:1900,running_loss:0.011555710740503855
# epoch:1,batch_idx:2000,running_loss:0.004534667397383601
# epoch:1,batch_idx:2100,running_loss:0.026465356321423314
# epoch:1,batch_idx:100,running_loss:0.015623202288115862
# epoch:1,batch_idx:200,running_loss:0.005023970066104084
# epoch:1,batch_idx:300,running_loss:0.018747255770722403
# epoch:1,batch_idx:400,running_loss:0.03081673283013515
# epoch:1,batch_idx:500,running_loss:0.0776880026073195
# epoch:1,batch_idx:600,running_loss:0.1386964154674206
# epoch:1,batch_idx:700,running_loss:0.16610738022252916
# epoch:1,batch_idx:800,running_loss:0.2088785587158054
# epoch:1,batch_idx:900,running_loss:0.2836479915957898
# epoch:1,batch_idx:1000,running_loss:0.3859398434776813
# epoch:1,batch_idx:1100,running_loss:0.2146111747995019
# epoch:1,batch_idx:1200,running_loss:0.24940075956285
# epoch:1,batch_idx:1300,running_loss:0.09409101979574189
# epoch:1,batch_idx:1400,running_loss:0.16206753720063716
# epoch:1,batch_idx:1500,running_loss:0.10859891963656992
# epoch:1,batch_idx:1600,running_loss:0.07688239228096791
# epoch:1,batch_idx:1700,running_loss:0.02771483516902663
# epoch:1,batch_idx:1800,running_loss:0.02326035298523493
# epoch:1,batch_idx:1900,running_loss:0.01327999783330597
# epoch:1,batch_idx:2000,running_loss:0.004214422602090053
# epoch:1,batch_idx:2100,running_loss:0.023620447260909713
# epoch:1,batch_idx:100,running_loss:0.016891087025287563
# epoch:1,batch_idx:200,running_loss:0.0050810958456713705
# epoch:1,batch_idx:300,running_loss:0.024168473741738125
# epoch:1,batch_idx:400,running_loss:0.03219515509903431
# epoch:1,batch_idx:500,running_loss:0.07733366833475884
# epoch:1,batch_idx:600,running_loss:0.14736346916877666
# epoch:1,batch_idx:700,running_loss:0.15421472305548378
# epoch:1,batch_idx:800,running_loss:0.2055765860597603
# epoch:1,batch_idx:900,running_loss:0.30036484528332946
# epoch:1,batch_idx:1000,running_loss:0.39438750674016776
# epoch:1,batch_idx:1100,running_loss:0.20636970654129982
# epoch:1,batch_idx:1200,running_loss:0.25947317842859774
# epoch:1,batch_idx:1300,running_loss:0.09417775869602338
# epoch:1,batch_idx:1400,running_loss:0.1526652745436877
# epoch:1,batch_idx:1500,running_loss:0.10829935579095036
# epoch:1,batch_idx:1600,running_loss:0.09089209954021499
# epoch:1,batch_idx:1700,running_loss:0.02587562185479328
# epoch:1,batch_idx:1800,running_loss:0.024404672557138837
# epoch:1,batch_idx:1900,running_loss:0.014504605500260368
# epoch:1,batch_idx:2000,running_loss:0.005182246558833867
# epoch:1,batch_idx:2100,running_loss:0.023418702162452974
# epoch:1,batch_idx:100,running_loss:0.012854338033939712
# epoch:1,batch_idx:200,running_loss:0.005112789597478695
# epoch:1,batch_idx:300,running_loss:0.024290196545771324
# epoch:1,batch_idx:400,running_loss:0.02996156579174567
# epoch:1,batch_idx:500,running_loss:0.08208832372096367
# epoch:1,batch_idx:600,running_loss:0.14891947417287155
# epoch:1,batch_idx:700,running_loss:0.17345707035274244
# epoch:1,batch_idx:800,running_loss:0.20467579527990892
# epoch:1,batch_idx:900,running_loss:0.2661514507140964
# epoch:1,batch_idx:1000,running_loss:0.41503400180488825
# epoch:1,batch_idx:1100,running_loss:0.2056090877857059
# epoch:1,batch_idx:1200,running_loss:0.23553560459986328
# epoch:1,batch_idx:1300,running_loss:0.09396740796044468
# epoch:1,batch_idx:1400,running_loss:0.15899178838822992
# epoch:1,batch_idx:1500,running_loss:0.10507933919783681
# epoch:1,batch_idx:1600,running_loss:0.09280051413923501
# epoch:1,batch_idx:1700,running_loss:0.02516226582345553
# epoch:1,batch_idx:1800,running_loss:0.027030045409919694
# epoch:1,batch_idx:1900,running_loss:0.01665137961972505
# epoch:1,batch_idx:2000,running_loss:0.007730945990770124
# epoch:1,batch_idx:2100,running_loss:0.021705879316432402
# epoch:1,batch_idx:100,running_loss:0.013035797365009785
# epoch:1,batch_idx:200,running_loss:0.005114876886946149
# epoch:1,batch_idx:300,running_loss:0.02534772574203089
# epoch:1,batch_idx:400,running_loss:0.02608016134996433
# epoch:1,batch_idx:500,running_loss:0.07905759354500333
# epoch:1,batch_idx:600,running_loss:0.14285395542508922
# epoch:1,batch_idx:700,running_loss:0.1818241702450905
# epoch:1,batch_idx:800,running_loss:0.19943325587548316
# epoch:1,batch_idx:900,running_loss:0.2623347661504522
# epoch:1,batch_idx:1000,running_loss:0.4388602526020259
# epoch:1,batch_idx:1100,running_loss:0.203743964349851
# epoch:1,batch_idx:1200,running_loss:0.2560800175461918
# epoch:1,batch_idx:1300,running_loss:0.0957033778494224
# epoch:1,batch_idx:1400,running_loss:0.15768457407597453
# epoch:1,batch_idx:1500,running_loss:0.10490397132700309
# epoch:1,batch_idx:1600,running_loss:0.09765314131509513
# epoch:1,batch_idx:1700,running_loss:0.02557665149564855
# epoch:1,batch_idx:1800,running_loss:0.025710943564772607
# epoch:1,batch_idx:1900,running_loss:0.018214574640151113
# epoch:1,batch_idx:2000,running_loss:0.0071662312390981244
# epoch:1,batch_idx:2100,running_loss:0.017081563791434745
# epoch:1,batch_idx:100,running_loss:0.01396229888079688
# epoch:1,batch_idx:200,running_loss:0.0057427893212297935
# epoch:1,batch_idx:300,running_loss:0.023681249676446896
# epoch:1,batch_idx:400,running_loss:0.027069858367904088
# epoch:1,batch_idx:500,running_loss:0.08653948679566384
# epoch:1,batch_idx:600,running_loss:0.13965064633870497
# epoch:1,batch_idx:700,running_loss:0.18184726007748395
# epoch:1,batch_idx:800,running_loss:0.20280536560341716
# epoch:1,batch_idx:900,running_loss:0.25713946195784954
# epoch:1,batch_idx:1000,running_loss:0.47398361316882076
# epoch:1,batch_idx:1100,running_loss:0.19761944963596761
# epoch:1,batch_idx:1200,running_loss:0.2163277403637767
# epoch:1,batch_idx:1300,running_loss:0.10916777776321396
# epoch:1,batch_idx:1400,running_loss:0.15401656549191103
# epoch:1,batch_idx:1500,running_loss:0.12768655363237486
# epoch:1,batch_idx:1600,running_loss:0.09891074540908448
# epoch:1,batch_idx:1700,running_loss:0.026122657558880748
# epoch:1,batch_idx:1800,running_loss:0.026224376837490126
# epoch:1,batch_idx:1900,running_loss:0.019491356881335378
# epoch:1,batch_idx:2000,running_loss:0.007713267485960387
# epoch:1,batch_idx:2100,running_loss:0.017309068447502796
# epoch:1,batch_idx:100,running_loss:0.013935694574320224
# epoch:1,batch_idx:200,running_loss:0.005805618971935473
# epoch:1,batch_idx:300,running_loss:0.0228008483137819
# epoch:1,batch_idx:400,running_loss:0.026423713981639594
# epoch:1,batch_idx:500,running_loss:0.08694061627436894
# epoch:1,batch_idx:600,running_loss:0.1358948249858804
# epoch:1,batch_idx:700,running_loss:0.17513892726041377
# epoch:1,batch_idx:800,running_loss:0.197991854660213
# epoch:1,batch_idx:900,running_loss:0.2546172256907448
# epoch:1,batch_idx:1000,running_loss:0.43710508272983134
# epoch:1,batch_idx:1100,running_loss:0.20974458505399526
# epoch:1,batch_idx:1200,running_loss:0.2585764368530363
# epoch:1,batch_idx:1300,running_loss:0.11162981755333021
# epoch:1,batch_idx:1400,running_loss:0.15137345485389234
# epoch:1,batch_idx:1500,running_loss:0.10646361835999414
# epoch:1,batch_idx:1600,running_loss:0.10363011287758127
# epoch:1,batch_idx:1700,running_loss:0.02640357249067165
# epoch:1,batch_idx:1800,running_loss:0.027131687916116788
# epoch:1,batch_idx:1900,running_loss:0.020088161804014817
# epoch:1,batch_idx:2000,running_loss:0.008321726216818206
# epoch:1,batch_idx:2100,running_loss:0.01687566725508077
# epoch:1,batch_idx:100,running_loss:0.011253691144520416
# epoch:1,batch_idx:200,running_loss:0.00606264655754785
# epoch:1,batch_idx:300,running_loss:0.025521956196753307
# epoch:1,batch_idx:400,running_loss:0.022751652266015297
# epoch:1,batch_idx:500,running_loss:0.08685367437719833
# epoch:1,batch_idx:600,running_loss:0.12925730409100653
# epoch:1,batch_idx:700,running_loss:0.17925607661949472
# epoch:1,batch_idx:800,running_loss:0.2153160480526276
# epoch:1,batch_idx:900,running_loss:0.25287574654910716
# epoch:1,batch_idx:1000,running_loss:0.45389311990700665
# epoch:1,batch_idx:1100,running_loss:0.21235829218756408
# epoch:1,batch_idx:1200,running_loss:0.2504907082999125
# epoch:1,batch_idx:1300,running_loss:0.13224098200444132
# epoch:1,batch_idx:1400,running_loss:0.1521702434681356
# epoch:1,batch_idx:1500,running_loss:0.110972266709432
# epoch:1,batch_idx:1600,running_loss:0.09150487271137536
# epoch:1,batch_idx:1700,running_loss:0.027406329405494034
# epoch:1,batch_idx:1800,running_loss:0.026836112946039065
# epoch:1,batch_idx:1900,running_loss:0.01952100756810978
# epoch:1,batch_idx:2000,running_loss:0.007713826511462685
# epoch:1,batch_idx:2100,running_loss:0.014513756996893789
# epoch:1,batch_idx:100,running_loss:0.011947429937426932
# epoch:1,batch_idx:200,running_loss:0.006530621918791439
# epoch:1,batch_idx:300,running_loss:0.026196009178238455
# epoch:1,batch_idx:400,running_loss:0.024295983904739842
# epoch:1,batch_idx:500,running_loss:0.087703638728417
# epoch:1,batch_idx:600,running_loss:0.14298660554923118
# epoch:1,batch_idx:700,running_loss:0.17962781343259848
# epoch:1,batch_idx:800,running_loss:0.2390598861547187
# epoch:1,batch_idx:900,running_loss:0.2587069979915395
# epoch:1,batch_idx:1000,running_loss:0.4445694354735315
# epoch:1,batch_idx:1100,running_loss:0.23234438947401942
# epoch:1,batch_idx:1200,running_loss:0.27068376102484765
# epoch:1,batch_idx:1300,running_loss:0.1311834494723007
# epoch:1,batch_idx:1400,running_loss:0.1546841802680865
# epoch:1,batch_idx:1500,running_loss:0.11774036827264353
# epoch:1,batch_idx:1600,running_loss:0.10137703833635897
# epoch:1,batch_idx:1700,running_loss:0.02809316020109691
# epoch:1,batch_idx:1800,running_loss:0.025013031208654866
# epoch:1,batch_idx:1900,running_loss:0.02155140331480652
# epoch:1,batch_idx:2000,running_loss:0.007920884952472989
# epoch:1,batch_idx:2100,running_loss:0.014430005536123645
# epoch:1,batch_idx:100,running_loss:0.012216629884496797
# epoch:1,batch_idx:200,running_loss:0.0066008409738424235
# epoch:1,batch_idx:300,running_loss:0.022692103574518115
# epoch:1,batch_idx:400,running_loss:0.02349836986977607
# epoch:1,batch_idx:500,running_loss:0.090988048571744
# epoch:1,batch_idx:600,running_loss:0.1354560068680439
# epoch:1,batch_idx:700,running_loss:0.17509650225751103
# epoch:1,batch_idx:800,running_loss:0.2410413416288793
# epoch:1,batch_idx:900,running_loss:0.2645940712187439
# epoch:1,batch_idx:1000,running_loss:0.4385313217109069
# epoch:1,batch_idx:1100,running_loss:0.2275537113053724
# epoch:1,batch_idx:1200,running_loss:0.2585906697856262
# epoch:1,batch_idx:1300,running_loss:0.14176832676399498
# epoch:1,batch_idx:1400,running_loss:0.1600241246446967
# epoch:1,batch_idx:1500,running_loss:0.1137906902655959
# epoch:1,batch_idx:1600,running_loss:0.08861988455057145
# epoch:1,batch_idx:1700,running_loss:0.027604096801951528
# epoch:1,batch_idx:1800,running_loss:0.02501893520937301
# epoch:1,batch_idx:1900,running_loss:0.01902395279612392
# epoch:1,batch_idx:2000,running_loss:0.007626264176797122
# epoch:1,batch_idx:2100,running_loss:0.012515942155150696
# ###epoch:1,train_loss:0.2889890670776367

# %%
def save_net(path = 'wind.pt', net=None):
    torch.save(net.state_dict(),path)
save_net(net=net)

# %%
def load_net(path='wind_cpu.pt',net=None):
    net.load_state_dict(torch.load(path))
load_net(net=net)

# %%
def predict(prefix,num_preds,net,device):
    state = net.begin_state(batch_size=1,device=device)
    outputs = [prefix[0]]
    get_input = lambda:torch.tensor([outputs[-1]],device=device).reshape(1,1)
    for y in prefix[1:]:
        _,state = net(get_input(),state)
        outputs.append(y)
    for _ in range(num_preds):
        y,state = net(get_input(),state)
        outputs.append(y.reshape(1).detach()[0])
    tmp = []
    for t in outputs:
        tmp.append(t.item())
    outputs =tmp
    return outputs#torch.cat(outputs,dim=1)

# %%
test_dataset = WindDataSet('../data/wind_dataset144-2014/wind_dataset144/142.csv',num_steps=50)
test_loader = DataLoader(test_dataset,batch_size=1,shuffle=False)
preds,truth=None,None
for batch_idx,(X, y) in enumerate(test_loader):
    if batch_idx == 0:
        X = (X.reshape(-1).to(torch.float32))
        preds = predict(X,50,net,device)
    if batch_idx == 1:
        truth = np.array(X)
        break
print((preds[50:]))
print((truth.reshape(50)))
# Out:
# [6.985098838806152, 7.161799430847168, 7.4930925369262695, 7.9666666984558105, 8.546405792236328, 9.145689964294434, 9.714990615844727, 10.25847339630127, 10.766324996948242, 11.239696502685547, 11.693398475646973, 12.125823974609375, 12.534660339355469, 12.923495292663574, 13.292140007019043, 13.64033031463623, 13.969825744628906, 14.281046867370605, 14.57377815246582, 14.848335266113281, 15.104844093322754, 15.34335708618164, 15.56422233581543, 15.767910957336426, 15.954975128173828, 16.12609100341797, 16.282011032104492, 16.42353630065918, 16.551515579223633, 16.66683006286621, 16.770366668701172, 16.863008499145508, 16.945615768432617, 17.019012451171875, 17.0839786529541, 17.141246795654297, 17.191499710083008, 17.23537254333496, 17.273448944091797, 17.3062686920166, 17.33432388305664, 17.358062744140625, 17.377893447875977, 17.394187927246094, 17.40727424621582, 17.417449951171875, 17.424985885620117, 17.43012809753418, 17.433107376098633, 17.43414878845215]
# [9.1  9.14 9.15 9.13 9.13 9.08 8.9  8.67 8.52 8.53 8.64 8.74 8.88 9.07
#  9.17 9.14 9.09 9.05 8.98 8.87 8.8  8.82 8.78 8.72 8.68 8.69 8.79 9.
#  9.17 9.08 8.85 8.57 8.3  8.1  7.86 7.57 7.28 6.98 6.8  6.86 7.1  7.33
#  7.42 7.38 7.22 7.03 6.93 6.96 6.96 6.9 ]
